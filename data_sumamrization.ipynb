# %%
import re
import pandas as pd
# Load the excel file
def load_excel(file_path):
    return pd.read_excel(file_path)

# Normalize the plant names to handle variations like punctuation, capitalization, and parentheses
def normalize_name(name):
    # Remove special characters like punctuation and parentheses, convert to lowercase
    return re.sub(r'[.,;()\\[\\]]', '', name.strip().lower())

# Function to find rows with similar scientific names or partial matches
def find_similar_rows(df, plant_name_column, target_name):
    normalized_target = normalize_name(target_name)
    
    def match_plant_name(cell):
        # Split plant names by commas, 'and', or other delimiters to handle multiple names in a single cell
        names_in_cell = re.split(r',| and ', str(cell))
        # Check if the target name (or a variation) appears in the cell
        # print(names_in_cell)
        return any(normalized_target in normalize_name(name) for name in names_in_cell)
    
    # Apply the match_plant_name function to each row in the specified column
    similar_rows = df[df[plant_name_column].apply(match_plant_name)]
    
    return similar_rows

# %%
# Load the file
df = load_excel('Extraction data new species.xlsx')
df.columns
# Out:
# Index(['filename', 'Title', 'Authors', 'Year',
#        'Scientific name of Medicinal plant', 'Medicinal use',
#        'Biological activity', 'Dose', 'Phytochemicals', 'Plant part used',
#        'Formulation', 'Botanic description', 'Toxicity', 'Adverse reactions',
#        'Health Benefits', 'Nutritional benefits', 'Reference'],
#       dtype='object')

# %%
system_prompt = """
You are an expert in scientific research, specifically in recognizing and extracting unique scientific names from research papers or datasets. You are given a document containing information about medicinal plants. Your task is to extract all unique scientific names of the plants mentioned.

Follow these guidelines carefully:
Recognize scientific names: Identify any text that corresponds to a scientific name of a plant. Scientific names are typically in Latin and often follow a binomial nomenclature format (e.g., Genus species). Variations with synonyms, subspecies, or other descriptors in parentheses should also be captured.
Ignore case and punctuation: Consider names to be the same if they only differ in capitalization, punctuation, or parentheses. For example:
Moringa oleifera is equivalent to Moringa oleifera Lam.
Zingiber officinale Roscoe is equivalent to Zingiber officinale.
Handle synonyms: If a name includes a synonym in parentheses (e.g., Aloe vera (synonym: Aloe barbadensis Miller)), treat the first part (Aloe vera) as the main name. Ensure that the core scientific name is extracted regardless of additional synonyms or subspecies mentioned.
Multiple names: If multiple scientific names are mentioned within the same text (separated by commas, "and", or "or"), extract each unique name.
No duplicates: Ensure that names are extracted only once. If the same scientific name appears in different variations, it should only be listed once in the final result.
Output format: The final output should be a list of unique scientific names, formatted as plain text or an array, with one name per entry.

Example input:

Moringa oleifera Lam
Moringa oleifera
Zingiber officinale Roscoe
Zingiber officinale Roscoe (Ginger)
Aloe vera (synonym: Aloe barbadensis Miller)
Expected output:

Moringa oleifera
Zingiber officinale
Aloe vera
Edge cases:

When synonyms or subspecies are provided (e.g., Aloe vera (synonym: Aloe barbadensis Miller)), only extract the main name (Aloe vera).
When there are small variations like missing author names (e.g., Zingiber officinale Roscoe vs. Zingiber officinale), consider them the same name.
"""

# %%
unique_text = """
Scientific name of Medicinal plant
Mentha x piperita L.
Athrixia phylicoides
Athrixia phylicoides
Athrixia phylicoides DC.
Athrixia phylicoides
Athrixia phylicoides
Camellia sinensis L., Melaleuca alternifolia
['Camellia sinensis', 'Camellia oleifera', 'Camellia japonica', 'Camellia taliensis', 'Camellia tenuiflora', 'Camellia vietnamensis', 'Camellia polyodontia', 'Camellia octopetala', 'Camellia meiocarpa', 'Camellia semiserrata', 'Camellia chekiangoleosa', 'Camellia fangchengensis', 'Camellia crassicolumna', 'Camellia osmantha', 'Camellia brevistyla']
Camellia sinensis (L.)
Camellia sinensis
Camellia sinensis
Camellia sinensis
Camellia sinensis
Camellia sinensis
Capsicum annuum L.
Capsicum annuum L.
Capsicum annuum
Capsicum annuum
Capsicum annuum, Capsicum frutescens, Capsicum chinense, Capsicum pubescens, Capsicum baccatum
Capsicum annuum L.
Capsicum annuum
Capsicum annuum L.
Capsicum annuum L., Capsicum chinense Jacq, Capsicum frutescens L., Capsicum baccatum L., Capsicum pubescens (Ruiz and Pav)
Centella asiatica (L.) Urban
Centella asiatica
Centella asiatica
Centella asiatica
Centella asiatica (L.) Urb.
Centella asiatica (also known as Centella asiatica (L.) Urb. or Gotu kola)
Centella asiatica (L.)
Centella asiatica
Centella asiatica
['Cinnamomum verum', 'Cinnamomum cassia', 'Cinnamomum burmanni', 'Cinnamomum tamala', 'Cinnamomum osmophloeum', 'Cinnamomum altissimum', 'Cinnamomum iners', 'Cinnamomum impressicostatum', 'Cinnamomum chemungianum', 'Cinnamomum micranthum', 'Cinnamomum porrectum', 'Cinnamomum subavenium', 'Cinnamomum tenuifolium', 'Cinnamomum kotoense']
['Cinnamomum aureofulvum Gamble', 'Cinnamomum bejolghota (Buch.-Ham.) Sweet', 'Cinnamomum burmannii (Nees & T. Nees) Blume', 'Cinnamomum cambodianum Lecomte', 'Cinnamomum caryophyllus (Lour.) S. Moore', 'Cinnamomum culilaban (L.) J. Presl', 'Cinnamomum filipedicellatum Kosterm.', 'Cinnamomum glanduliferum (Wall.) Meisn.', 'Cinnamomum glaucescens (Nees) Hand.-Mazz.', 'Cinnamomum iners Reinw. ex Blume', 'Cinnamomum insularimontanum Hayata', 'Cinnamomum javanicum Blume', 'Cinnamomum kotoense Kaneh. & Sasaki', 'Cinnamomum laubatii F.Muell', 'Cinnamomum loureiroi Nees', 'Cinnamomum macrocarpum Hook.f.', 'Cinnamomum mercadoi S.Vidal', 'Cinnamomum micranthum f. kanehirae (Hayata) S.S.Ying', 'Cinnamomum mollissimum Hook.f.', 'Cinnamomum oliveri F.M.Bailey', 'Cinnamomum osmophloeum Kaneh.', 'Cinnamomum parthenoxylon (Jack) Meisn.', 'Cinnamomum rhynchophyllum Miq.', 'Cinnamomum scortechinii Gamble', 'Cinnamomum sintoc Blume', 'Cinnamomum subavenium Miq.', 'Cinnamomum sulphuratum Nees', 'Cinnamomum tenuifolium (Makino) Sugim.', 'Cinnamomum travancoricum Gamble', 'Cinnamomum tazia (Buch.-Ham.) Kosterm. ex M.Gangop.', 'Cinnamomum walaiwarense Kosterm.', 'Cinnamomum wightii Meisn.', 'Cinnamomum wilsonii Gamble']
Cinnamomum zeylanicum, Cinnamomum loureirii, Cinnamomum burmanni, Cinnamomum aromaticum, Cinnamomum cassia
Cinnamomum zeylanicum, Cinnamomum cassia, Cinnamomum burmannii, Cinnamomum camphora, Cinnamomum osmophloeum, Cinnamomum verum
['Cinnamomum verum', 'Cinnamomum zeylanicum', 'Cinnamomum cassia', 'Cinnamomum aromaticum', 'Cinnamomum burmannii', 'Cinnamomum loureiroi']
Cinnamomum verum
Cinnamomum zeylanicum
Cinnamomum zeylanicum
Cinnamomum zeylanicum
Cinnamomum verum J.S. Presl
Cinnamomum zeylanicum
Cinnamomum burmannii, Cinnamomum cassia, Cinnamomum verum, Cinnamomum zeylanicum
['Cinnamomum zeylanicum', 'Cinnamomum cassia', 'Cinnamomum burmannii', 'Cinnamomum loureiroi', 'Cinnamomum osmophloeum', 'Cinnamomum camphora', 'Cinnamomum tamala', 'Cinnamomum altissimum']
Cinnamomum verum
Curcuma longa
Curcuma longa
Curcuma longa Linn
Curcuma longa
Curcuma longa
Curcuma longa
Curcuma longa Linn.
Curcuma longa L.
Curcuma longa
Curcuma longa
Curcuma longa Linn.
Curcuma longa
Curcuma longa L.
Curcuma longa Linn.
Curcuma longa
Curcuma longa
Cymbopogon citratus, Cymbopogon flexuosus
Cymbopogon citratus
Cymbopogon citratus
Cymbopogon citratus (DC.) Staph
Cymbopogon citratus (DC.) Stapf
Cymbopogon citratus
Cymbopogon citratus
Cymbopogon citratus (DC.) Stapf
Echinacea purpurea (L.) Moench
Echinacea purpurea, Echinacea angustifolia
Echinacea purpurea
Echinacea purpurea L.
Echinacea purpurea (L.) Moench
Echinacea purpurea (L.) Moench
Echinacea purpurea
['Echinacea purpurea (L.) Moench', 'Echinacea angustifolia DC.', 'Echinacea pallida (Nutt.) Nutt.']
['Echinacea angustifolia (DC.) Hell.', 'Echinacea pallida (Nutt.) Nutt.', 'Echinacea purpurea (L.) Moench']
Eucalyptus globulus
Eucalyptus globulus Labill.

Eucalyptus globulus
Eucalyptus globulus Labill.
['Eucalyptus globulus Labill.', 'Eucalyptus polybractea R.T. Baker', 'Eucalyptus smithii R.T. Baker']
Eucalyptus globulus
Eucalyptus globulus
Eucalyptus globulus
Eucalyptus globulus
Eucalyptus globulus Labill.
Jateorhiza palmata
Jateorhiza palmata (Lam.) Miers
Jateorhiza palmata
Jatropha gossypiifolia L.
Jatropha curcas, Jatropha gossypiifolia
Jatropha gossypifolia
Jatropha gossypifolia
Jatropha gossypiifolia L.
Jatropha gossypifolia L.
Jatropha gossypiifolia L.
Jatropha curcas L., Jatropha gossypifolia L., Jatropha multifidia L.
Jatropha gossypiifolia
Jatropha gossypifolia
Jatropha gossypifolia
Jatropha gossypiifolia L.
Kigelia africana (Lam.) Benth.
Kigelia africana (Lam.) Benth.
Kigelia africana (Lam.) Benth.
Kigelia africana (Lam.) Benth.
Kigelia africana
Kigelia africana (Lam.) Benth
Kigelia africana subsp. africana
Linum usitatissimum
Linum usitatissimum
Linum usitatissimum L.
Linum usitatissimum
Linum usitatissimum L.
Linum usitatissimum
Linum Usitatissimum
Linum usitatissimum
Linum usitatissimum L.
Linum usitatissimum L.
Mentha piperita
Mentha piperita L.
Mentha piperita L.
Mentha piperita
Mentha x piperita
Mentha Piperita Linn
Mentha piperita
Mentha piperita L., Mentha arvensis var. piperascens
Musa acuminata
Musa acuminata
Musa acuminata, Musa paradisiaca, Musa sapientum
Musa acuminata
Musa acuminata
Musa acuminata
Musa spp., Musa accuminata Colla, Musa balbisiana Colla
Musa spp., Musa paradisiaca, Musa acuminata
Musa acuminata, Musa balbisiana, Musa paradisiaca
Nigella sativa
Nigella sativa
Nigella sativa
Nigella sativa
Nigella sativa
Nigella sativa
Nigella sativa L.
Nigella sativa L.
Nigella sativa
Nigella sativa
Nigella sativa
Ocimum basilicum
Ocimum basilicum L.
Ocimum basilicum
Ocimum basilicum
Ocimum basilicum L.
Ocimum basilicum L.
['Ocimum americanum', 'Ocimum basilicum', 'Ocimum gratissimum', 'Ocimum campechianum', 'Ocimum sanctum']
Ocimum basilicum
Ocimum basilicum
Ocimum basilicum L.
Ocimum basilicum L.
Persea americana Mill
Persea americana
Persea americana
Persea americana Mill.
Persea americana
Persea americana
Persea americana Mill.
Persea americana var. drymifolia
['Piper nigrum L.', 'Piper aduncum L.', 'Piper betle L.', 'Piper auritum Kunth', 'Piper cernuum Vell.', 'Piper dilatatum Rich.', 'Piper gaudichaudianum Kunth', 'Piper guineense Schumach. & Thonn.', 'Piper marginatum Jacq.', 'Piper umbellatum L.', 'Piper tuberculatum Jacq.']
Persea americana
Piper nigrum L.
Piper nigrum
Piper nigrum
['Piper nigrum', 'Piper longum', 'Piper chaba', 'Piper guineense', 'Piper sarmentosum']
Salvia hispanica L.
Salvia hispanica L.
Salvia hispanica L.
Salvia hispanica L.
Salvia hispanica
Salvia hispanica L.
Taraxacum officinale
Taraxacum officinale
Taraxacum officinale
Taraxacum Officinale
Taraxacum officinale
Taraxacum officinale, Taraxacum japonicum, Taraxacum coreanum, Taraxacum platycarpum, Taraxacum formosanum, Taraxacum bicorne, Taraxacum hondoense, Taraxacum obovatum, Taraxacum bessarabicum, Taraxacum mongolicum
Taraxacum officinale Weber
['Taraxacum mongolicum Hand.-Mazz', 'Taraxacum officinale (L.) Weber ex F. H. Wigg', 'Taraxacum coreanum Nakai', 'Taraxacum borealisinense', 'Taraxacum platycarpum Dahlst.']
Taraxacum genus (Dandelion), including species like Taraxacum officinale, Taraxacum mongolicum, Taraxacum coreanum, Taraxacum formosanum, Taraxacum platycarpum
Taraxacum officinale F.H.Wigg.
Taraxacum officinale
Trigonella foenum-graecum L.
Trigonella foenum graecum
Trigonella foenum-graecum L.
Trigonella foenum-graecum
Trigonella foenum-graecum L.
Trigonella foenum-graecum
Trigonella foenum-graecum
Trigonella foenum-graecum
Trigonella foenum-graecum
Trigonella foenum-graecum
Trigonella foenum-graecum Linn.
"""

# %%
import os
from openai import OpenAI
import json
import time
plant_list = []
user_prompt = """you are an expert in extracting unique scientific names from a text, can you please extract the unique names from the text below, it should be in an rray, i just want the array result, make sure its unique and should be ordered by letters: """+ unique_text
try:
    client = OpenAI(
        # If the environment variable is not configured, replace the following line with: api_key="sk-xxx",
        api_key=QWEN_API_KEY,
        base_url="https://dashscope-intl.aliyuncs.com/compatible-mode/v1",
    )

    completion = client.chat.completions.create(
        model="qwen-plus",
        messages=[
            {'role': 'system', 'content': system_prompt},
            {'role': 'user', 'content': user_prompt}
            ]
    )
    print(completion.choices[0].message.content)
    plant_list = eval(completion.choices[0].message.content)
except Exception as e:
    print(f"Error message: {e}")
    print("For more information, see: https://www.alibabacloud.com/help/en/model-studio/developer-reference/error-code")
# Out:
# [
# "Athrixia phylicoides",
# "Capsicum annuum",
# "Capsicum baccatum",
# "Capsicum chinense",
# "Capsicum frutescens",
# "Capsicum pubescens",
# "Camellia chekiangoleosa",
# "Camellia crassicolumna",
# "Camellia fangchengensis",
# "Camellia japonica",
# "Camellia oleifera",
# "Camellia osmantha",
# "Camellia polyodontia",
# "Camellia sinensis",
# "Camellia taliensis",
# "Camellia tenuiflora",
# "Centella asiatica",
# "Cinnamomum altissimum",
# "Cinnamomum aromaticum",
# "Cinnamomum aureofulvum",
# "Cinnamomum bejolghota",
# "Cinnamomum burmannii",
# "Cinnamomum cambodianum",
# "Cinnamomum camphora",
# "Cinnamomum caryophyllus",
# "Cinnamomum chekiangoleosa",
# "Cinnamomum culilaban",
# "Cinnamomum filipedicellatum",
# "Cinnamomum glanduliferum",
# "Cinnamomum glaucescens",
# "Cinnamomum iners",
# "Cinnamomum insularimontanum",
# "Cinnamomum javanicum",
# "Cinnamomum kotoense",
# "Cinnamomum laubatii",
# "Cinnamomum loureiroi",
# "Cinnamomum loureirii",
# "Cinnamomum macrocarpum",
# "Cinnamomum mercadoi",
# "Cinnamomum micranthum",
# "Cinnamomum mollissimum",
# "Cinnamomum oliveri",
# "Cinnamomum osmophloeum",
# "Cinnamomum parthenoxylon",
# "Cinnamomum rhynchophyllum",
# "Cinnamomum scortechinii",
# "Cinnamomum sintoc",
# "Cinnamomum subavenium",
# "Cinnamomum sulphuratum",
# "Cinnamomum tamala",
# "Cinnamomum tenuifolium",
# "Cinnamomum travancoricum",
# "Cinnamomum tazia",
# "Cinnamomum verum",
# "Cinnamomum walaiwarense",
# "Cinnamomum wightii",
# "Cinnamomum wilsonii",
# "Curcuma longa",
# "Cymbopogon citratus",
# "Cymbopogon flexuosus",
# "Echinacea angustifolia",
# "Echinacea pallida",
# "Echinacea purpurea",
# "Eucalyptus globulus",
# "Eucalyptus polybractea",
# "Eucalyptus smithii",
# "Jateorhiza palmata",
# "Jatropha curcas",
# "Jatropha gossypiifolia",
# "Jatropha multifidia",
# "Kigelia africana",
# "Linum usitatissimum",
# "Mentha arvensis",
# "Mentha piperita",
# "Musa acuminata",
# "Musa balbisiana",
# "Musa paradisiaca",
# "Nigella sativa",
# "Ocimum americanum",
# "Ocimum basilicum",
# "Ocimum campechianum",
# "Ocimum gratissimum",
# "Ocimum sanctum",
# "Piper aduncum",
# "Piper auritum",
# "Piper betle",
# "Piper chaba",
# "Piper cernuum",
# "Piper dilatatum",
# "Piper guineense",
# "Piper gaudichaudianum",
# "Piper longum",
# "Piper marginatum",
# "Piper nigrum",
# "Piper sarmentosum",
# "Piper tuberculatum",
# "Piper umbellatum",
# "Persea americana",
# "Salvia hispanica",
# "Taraxacum bicorne",
# "Taraxacum borealisinense",
# "Taraxacum coreanum",
# "Taraxacum formosanum",
# "Taraxacum hondoense",
# "Taraxacum mongolicum",
# "Taraxacum obovatum",
# "Taraxacum platycarpum",
# "Taraxacum officinale",
# "Trigonella foenum-graecum"
# ]

# %%
def generate_context_data(data):
    context = ""
    
    for record in data:
        plant_info = ""
        plant_info += f"Medicinal Uses: {record.get('Medicinal use', 'Not mentioned')}\n"
        plant_info += f"Biological Activity: {record.get('Biological activity', 'Not mentioned')}\n"
        plant_info += f"Dose: {record.get('Dose', 'Not mentioned')}\n"
        plant_info += f"Phytochemicals: {record.get('Phytochemicals', 'Not mentioned')}\n"
        plant_info += f"Plant Part Used: {record.get('Plant part used', 'Not mentioned')}\n"
        plant_info += f"Formulation: {record.get('Formulation', 'Not mentioned')}\n"
        plant_info += f"Botanic Description: {record.get('Botanic description', 'Not mentioned')}\n"
        plant_info += f"Toxicity: {record.get('Toxicity', 'Not mentioned')}\n"
        plant_info += f"Adverse Reactions: {record.get('Adverse reactions', 'Not mentioned')}\n"
        plant_info += f"Health Benefits: {record.get('Health Benefits', 'Not mentioned')}\n"
        plant_info += f"Nutritional Benefits: {record.get('Nutritional benefits', 'Not mentioned')}\n"
        plant_info += f"Reference: {record.get('Reference', 'Not mentioned')}\n"
        plant_info += "--------------------------------------\n"
        context += plant_info
    
    return context

# %%
len(plant_list)
# Out:
# 109

# %%
plant_list = list(set(plant_list))

# %%
## summarizing code
summary_prompt = """
You are an expert in summarizing herbal medicine results from different sources or research papers, separated by "----", grouped together. Your task is to consolidate information across all sources into a structured summary for each plant. Ensure that the summarized output is provided in a well-structured JSON format based on the specified columns. For any missing information, mention "Not mentioned."

Only include the following fields in the JSON output:

1. Medicinal use(s): Provide a summary of the medicinal uses of the plant, considering all sources. Include a brief description of its applications in preventing, diagnosing, treating, or managing diseases.
2. Biological activity: Provide a concise summary of the biological activities of the plant, combining information across all sources.
3. Dose: Summarize dosage information (if mentioned), including typical amounts and units. Present multiple dosages as an array.
4. Phytochemicals: Consolidate the phytochemicals mentioned into an array.
5. Plant part used: Summarize the commonly used parts of the plant (e.g., root, leaves, bark). Present them as an array if multiple parts are mentioned.
6. Formulation: Provide a summary of the forms in which the plant is prepared or formulated (e.g., tablets, capsules, extracts). Use an array if multiple forms are mentioned.
7. Botanic description: Provide a summarized botanical description, consolidating the physical characteristics and growth habits.
8. Toxicity: Summarize any toxicity information. If mentioned across different sources, provide a general summary.
9. Adverse reactions: Summarize the adverse reactions mentioned across the sources.
10. Health benefits: Provide a summary of the key health benefits based on the papers.
11. Nutritional benefits: Provide a summary of the nutritional benefits, if mentioned.
12. References: Provide a consolidated array of references in APA style (7th edition). Each reference should include title, author(s), year of publication, journal name, volume, issue, page numbers, and DOI if available.

Ensure that the summary is concise and structured according to the specified fields. The output must be in valid JSON format. If certain sections are missing for a specific plant, reflect this in the output with "Not mentioned."

Edge cases to consider:
- Ensure all information from different sources (separated by "----") is grouped and consolidated correctly into the JSON format.
- Summarize descriptions (e.g., biological activity) concisely.
- Ensure the output contains only the information from the provided context.
"""

# %%
print(df)
# Out:
#                                               filename  \
# 0    assessment-report-mentha-x-piperita-l-folium-a...
# 1                   Athrixia phylicoides lehlo2013.pdf
# 2               Athrixia phylicoides Lerotholi2016.pdf
# 3                  Athrixia phylicoides Mohale2020.pdf
# 4                 Athrixia phylicoides Mokwena2021.pdf
# ..                                                 ...
# 198          Trigonella foenum-graecum Pushpa 2022.pdf
# 199          Trigonella foenum-graecum Savita 2008.pdf
# 200      Trigonella foenum-graecum Srinivasan 2006.pdf
# 201      Trigonellafoenum-graecum L Ahmadiani 1999.pdf
# 202         Trigonellafoenum-graecum L Kalyan 2016.pdf
#
#                                                  Title  \
# 0    Assessment Report on Mentha x piperita L., Fol...
# 1    Bush Tea (Athrixia Phylicoides Dc.) Success St...
# 2    Bush Tea (Athrixia phylicoides): A review of t...
# 3    Untargeted Profiling Of Field Cultivated Bush ...
# 4    Athrixia phylicoides Tea Infusion (Bushman Tea...
# ..                                                 ...
# 198  Review Fenugreek (Trigonella foenum-graecum): ...
# 199  Analgesic And Anti-Inflammatory Activities Of ...
# 200  Fenugreek (Trigonella foenum-graecum): A Revie...
# 201  Anti-Inflammatory and Antipyretic Effects of T...
# 202  A Small Plant with Big Benefits: Fenugreek (Tr...
#
#                                                Authors  Year  \
# 0    Helena Pinto Ferreira, Zoi Karampourmpouni, Io...  2020
# 1    aNchabeleng Lehlohonolo, bIrvine K. Mariga, aW...  2013
# 2    L. Lerotholi, S.K. Chaudhary, S. Combrinck, A....  2017
# 3    Mohale K. Cecilia, Assress H. Abrha, Nyoni Hle...  2020
# 4    Madigoahle A. M. Mokwena, Godwill Azeh Engwa, ...  2021
# ..                                                 ...   ...
# 198  Pushpa Ruwalia, Niharika Pandeya, Khusboo Jind...  2022
# 199  Savita Vyas, Rajendra Prasad Agrawal, Pooja So...  2008
# 200                                      K. Srinivasan  2006
# 201  A. Ahmadiani, M. Javan, S. Semnanian, E. Barat...  2001
# 202  Kalyan C. Nagulapalli Venkata, Anand Swaroop, ...  2017
#
#     Scientific name of Medicinal plant  \
# 0                 Mentha x piperita L.
# 1                 Athrixia phylicoides
# 2                 Athrixia phylicoides
# 3             Athrixia phylicoides DC.
# 4                 Athrixia phylicoides
# ..                                 ...
# 198          Trigonella foenum-graecum
# 199          Trigonella foenum-graecum
# 200          Trigonella foenum-graecum
# 201          Trigonella foenum-graecum
# 202    Trigonella foenum-graecum Linn.
#
#                                          Medicinal use  \
# 0    Peppermint leaves are used for symptomatic rel...
# 1    Used as a cough remedy, purgative, aphrodisiac...
# 2    The plant is used traditionally for treating s...
# 3    Used as a health beverage and medicine for tre...
# 4    The Athrixia phylicoides tea infusion is used ...
# ..                                                 ...
# 198  Used for treating diabetes, hypertension, athe...
# 199  Treatment of pain and inflammation, traditiona...
# 200  Used as an antibacterial, gastric stimulant, a...
# 201  The leaves extract of Trigonella foenum-graecu...
# 202  Fenugreek is used as an antidiabetic, antihype...
#
#                                    Biological activity  \
# 0    The primary pharmacodynamic effects include an...
# 1    Aqueous extracts stimulate in vitro glucose up...
# 2    A. phylicoides exhibits antidiabetic, anti-inf...
# 3    The metabolites identified in Athrixia phylico...
# 4    The biological activities of Athrixia phylicoi...
# ..                                                 ...
# 198  Fenugreek exhibits anti-biotic, anti-oxidant, ...
# 199  The partially purified fraction (MTH) from Tri...
# 200  The biological activities include antidiabetic...
# 201  The extract exhibits potent anti-inflammatory ...
# 202  Fenugreek exhibits antioxidative, anti-inflamm...
#
#                                                   Dose  \
# 0    For peppermint leaves: 1.5-3.0 g of dried leav...
# 1                                        Not mentioned
# 2                                        Not mentioned
# 3                                        Not mentioned
# 4    50 mg/Kg BW and 100 mg/Kg BW (equivalent to 1 ...
# ..                                                 ...
# 198                                      Not mentioned
# 199  For analgesic studies: 10-40 mg/kg p.o.; For a...
# 200  Dosages range from 15g/day for NIDDM patients ...
# 201  Single dose: TFG 500, 1000, and 2000 mg/kg (i....
# 202  Clinical studies indicate doses ranging from 2...
#
#                                         Phytochemicals  \
# 0    Menthol, menthone, limonene, cineole, menthofu...
# 1    5 hydroxy-6, 7, 8, 3׳, 4׳, 5׳-hexamethoxyflavo...
# 2    Flavonoids (e.g., quercetin, 5-hydroxy-6,7,8,3...
# 3    Chlorogenate, chrysosplenetin, coumarin, narin...
# 4    Trans-cinnamic acid, syringaldehyde, vanillic ...
# ..                                                 ...
# 198  Alkaloids, flavonoids, saponins, fibers, fatty...
# 199  Glycoside, steroid, saponins (in seeds), alkal...
# 200  Saponins, alkaloids (including trigonelline), ...
# 201  Alkaloids, cardiac glycosides, phenols, trace ...
# 202  Steroids, alkaloids, saponins, polyphenols, fl...
#
#                                        Plant part used  \
# 0    Whole or cut dried leaf and essential oil obta...
# 1                                        Leaves, roots
# 2                   Leaves, twigs, roots, aerial parts
# 3                                     Leaves and twigs
# 4                                               Leaves
# ..                                                 ...
# 198                     Seeds, leaves, husk, endosperm
# 199                                              Seeds
# 200  Seeds and leaves are primarily used for medici...
# 201                                             Leaves
# 202  Seeds, leaves, endosperm, whole plant, aerial ...
#
#                                            Formulation  \
# 0    Herbal tea, tincture (ratio of herbal substanc...
# 1               Herbal tea, decoction, aqueous extract
# 2    Infusions, decoctions, aqueous and ethanol ext...
# 3    Extract prepared using 0.1% formic acid in met...
# 4    Tea infusion prepared by steeping dried leaves...
# ..                                                 ...
# 198  Tea, powder, extract, seed flour, aqueous extr...
# 199  Partially purified fraction (MTH) obtained fro...
# 200  Fenugreek is used in the form of powder, decoc...
# 201  Decoction of dried leaves in water, concentrat...
# 202  Extracts (aqueous, ethanolic, methanolic), see...
#
#                                    Botanic description  \
# 0                                        Not mentioned
# 1    Bush tea is a herbaceous plant of the Asterace...
# 2    A. phylicoides is an aromatic, perennial, leaf...
# 3                                        Not mentioned
# 4                                        Not mentioned
# ..                                                 ...
# 198  Fenugreek is an erect, branched herb growing u...
# 199                                      Not mentioned
# 200  Fenugreek is a leguminous herb that grows up t...
# 201                                      Not mentioned
# 202  Fenugreek is a short-living annual plant belon...
#
#                                               Toxicity  \
# 0    Peppermint oil may cause severe gastrointestin...
# 1    No phytoxicity was reported. A toxicological a...
# 2    Studies indicate low toxicity, with no detrime...
# 3                                        Not mentioned
# 4                  No toxic effects even at high doses
# ..                                                 ...
# 198                                      Not mentioned
# 199                                      Not mentioned
# 200                                     Not mentioned.
# 201  No acute toxicity was observed with chronic ad...
# 202  Fenugreek is generally recognized as safe (GRA...
#
#                                      Adverse reactions  \
# 0    Heartburn, perianal burning, blurred vision, d...
# 1                                        Not mentioned
# 2                                        Not mentioned
# 3                                        Not mentioned
# 4                                        Not mentioned
# ..                                                 ...
# 198                                      Not mentioned
# 199  No gross behavioral changes, sedation, morbidi...
# 200  Fenugreek extract and leaf must be contraindic...
# 201                                      Not mentioned
# 202  Minor adverse events such as increased inciden...
#
#                                        Health Benefits  \
# 0    Relieves IBS symptoms, reduces abdominal pain,...
# 1    Potential health benefits include anti-diabeti...
# 2    Potential health benefits include enhanced glu...
# 3    The compounds found in bush tea have a wide ra...
# 4    Improves adipokine balance, glucose homeostasi...
# ..                                                 ...
# 198  Improves glucose metabolism, reduces cholester...
# 199  Significant analgesic and anti-inflammatory ef...
# 200  Antidiabetic, hypocholesterolemic, antioxidant...
# 201  The extract has potential health benefits as a...
# 202  Fenugreek improves glycemic control, reduces h...
#
#                                   Nutritional benefits  \
# 0                                        Not mentioned
# 1                                        Not mentioned
# 2    Rich in phenolic compounds, non-structural car...
# 3                                        Not mentioned
# 4                                        Not mentioned
# ..                                                 ...
# 198  Rich in dietary fiber, protein, vitamins, and ...
# 199                                      Not mentioned
# 200  Rich in dietary fiber, protein, vitamins (espe...
# 201                                      Not mentioned
# 202  Rich in vitamins A, B1, B2, C, niacin, nicotin...
#
#                                              Reference
# 0    Ferreira, H. P., Karampourmpouni, Z., & Chinou...
# 1    Lehlohonolo, A., Mariga, I. K., Ngezimana, W.,...
# 2    Lerotholi, L., Chaudhary, S. K., Combrinck, S....
# 3    Mohale, K. C., Abrha, A. H., Nyoni, H., Hintsa...
# 4    Mokwena, M. A. M., Engwa, G. A., Nkeh-Chungag,...
# ..                                                 ...
# 198  Ruwali, P., Pandey, N., Jindal, K., & Singh, R...
# 199  Vyas, S., Agrawal, R. P., Solanki, P., & Tripa...
# 200  Srinivasan, K. (2006). Fenugreek (Trigonella f...
# 201  Ahmadiani, A., Javan, M., Semnanian, S., Barat...
# 202  Nagulapalli Venkata, K. C., Swaroop, A., Bagch...
#
# [203 rows x 17 columns]

# %%
data = []
#plant_list = ["Moringa oleifera"]
for target_name in plant_list:
    try:
        matching_rows = find_similar_rows(df, 'Scientific name of Medicinal plant', target_name)
    except Exception as e:
        # print(e)
        continue
    # Convert the dataframe to a list of dictionaries (each record is a plant)
    data_records = matching_rows.to_dict(orient='records')
    context_text = generate_context_data(data_records)
    # print(target_name)
    print(context_text)
    user_prompt = """Here is the information for {target_name} with each record seperated by ---. Summarize the information as per the structure provided, the output should be in a json format as text. 
    All information on the plant:
    """+ context_text
    try:
        client = OpenAI(
            # If the environment variable is not configured, replace the following line with: api_key="sk-xxx",
            api_key=QWEN_API_KEY,
            base_url="https://dashscope-intl.aliyuncs.com/compatible-mode/v1",
        )

        completion = client.chat.completions.create(
            model="qwen-plus",
            messages=[
                {'role': 'system', 'content': summary_prompt},
                {'role': 'user', 'content': user_prompt}
                ]
        )
        print(completion.choices[0].message.content)
        raw_output = completion.choices[0].message.content
        json_start = raw_output.find('{')
        json_end = raw_output.rfind('}') + 1
        json_str = raw_output[json_start:json_end]
        json_output = json.loads(json_str)
        # Append to the data list with filename as a key
        data.append({"Scientific name of Medicinal plant": target_name, **json_output})
        print(len(data))
    except Exception as e:
        print(f"Error message: {e}")
        print("For more information, see: https://www.alibabacloud.com/help/en/model-studio/developer-reference/error-code")
    time.sleep(2)  # Sleep for 1 second to avoid rate limiting

# Convert to DataFrame
data_df = pd.DataFrame(data)
# Export DataFrame to an Excel file
data_df.to_excel("summary_output.xlsx", index=False)
#print(sum)
# Out:
# Medicinal Uses: The Cinnamomum plants have been traditionally used to treat respiratory viruses, urinary tract infections, relieve abdominal discomfort, improve digestion, act as antidiabetic, analgesic, and neuroprotective agents.
# Biological Activity: Cinnamomum species exhibit antibacterial, antidiabetic, antioxidant, anti-inflammatory, anticancer, and neuroprotective activities. These effects are mediated through various mechanisms such as inhibiting bacterial growth, stimulating insulin secretion, scavenging free radicals, reducing inflammation by inhibiting NF-κB, inducing apoptosis in cancer cells, and protecting neurons from oxidative stress.
# Dose: Doses applied in randomized clinical trials vary between 1 g/day to 6 g/day. For cinnamon oil, the dose varies between 50 mg/day to 200 mg/day. Specific doses mentioned include 1.5 g/day for polycystic ovary syndrome (PCOS) patients and 3 g/day for type 2 diabetic patients.
# Phytochemicals: ['cinnamaldehyde', 'eugenol', 'trans-cinnamyl acetate', 'benzaldehyde', 'linalool', 'catechin', 'procyanidins', 'cinnamic acid', 'β-sitosterol', 'flavanol glucosides', 'coumarin', 'protocatechuic acid', 'vanillic acid', 'syringic acid', 'butanolides', 'terpenoids', 'lignans', 'diterpenoids', 'phenolic acids', 'cinncassiols', 'cinnzeylanol', 'cinnzeylanine', 'anhydrocinnzeylanol', 'anhydrocinnzeylanin', 'benzyl isoquinoline alkaloids', 'pentacyclic diterpenes', 'acetyl derivative', 'mannitol', 'xylose', 'arabinose', 'xylanose', 'glucose', 'mucilage', 'polysaccharides', 'subamolide D', 'subamolide E', 'subamolide B', 'subamolide A', 'apigenin', 'kaempferol', 'quercetin']
# Plant Part Used: Bark, leaf, root bark, fruits, buds, flowers, stem, twig
# Formulation: Essential oils, aqueous extracts, methanol extracts, ethanol extracts, chloroform extracts, capsules, tablets, powder
# Botanic Description: Not mentioned
# Toxicity: Coumarin found in cinnamon can negatively influence the liver, and high levels of cinnamaldehyde might correlate with liver damage and increased risk of cancer. When consumed in excess, cinnamon can cause respiratory distress, increase pulse rate, sweating process, depressive states, aggravation of rosacea symptoms, and increased risk of oral cancer.
# Adverse Reactions: Gastrointestinal problems, dermatitis, steatites, allergic reactions, low blood sugar, mouth sores, breathing problems, interactions with certain medications like statins, acetaminophen, amiodarone, carbamazepine, medicines treating fungal infections, methotrexate, and methyldopa.
# Health Benefits: Cinnamomum plants promote human health by providing antibacterial, antidiabetic, antioxidant, anti-inflammatory, anticancer, and neuroprotective benefits. They can be consumed daily in diets without harmful effects and may serve as disease-preventive agents.
# Nutritional Benefits: Cinnamon is a source of iron, calcium, manganese, and dietary fiber. It also has properties that stimulate collagen synthesis and inhibit osteoclastogenesis, which could be beneficial for skin anti-aging treatments and bone health respectively.
# Reference: Shariﬁ-Rad, J., Dey, A., Koirala, N., Shaheen, S., El Omari, N., Salehi, B., et al. (2021). Cinnamomum Species: Bridging Phytochemistry Knowledge, Pharmacological Properties and Toxicological Safety for Health Beneﬁts. Frontiers in Pharmacology, 12, Article 600139. https://doi.org/10.3389/fphar.2021.600139
# --------------------------------------
# Medicinal Uses: Used as antiemetic, antidiarrhoeal, anti-flatulent, stimulant agent in Ayurvedic medicine; cure for type 2 diabetes mellitus and insulin resistance; antimicrobial activity against various ailments such as cough, cold, diarrhoea, dysentery, flatulence, rheumatism, etc.; treatment for arthritis, anaemia, abdominal pain, asthma, bronchitis, urinary infection, menstrual problems, wounds, among others.
# Biological Activity: The plant extracts possess astringent, warming stimulant, carminative, blood purifier, digestive, antiseptic, antifungal, antiviral, antibacterial, antioxidant, anti-inflammatory, immunomodulatory properties, along with the ability to reduce cholesterol and blood sugar levels.
# Dose: Not mentioned
# Phytochemicals: ['Aldehydes', 'Acetate', 'Alcohol', 'Terpinenes', 'Flavonoids', 'Coumarins', 'Phenols', 'Saponins', 'Tannins', 'Carboxylic acid', 'Hydrocarbons', 'Camphene', 'Spathulenol', 'Fatty acids', 'Actinodaphnine', 'Butanolides', 'Kaempferol glycosides', 'Procyanidins', 'Catechins', 'Safrole', 'Methyl eugenol', 'Polysaccharides', 'Dehydrosulfurenic acid', '15a-acetyldehydrosulfurenic acid', 'Benzoic acid', 'Hexadecanoic acid', 'Octadecanoic acid', 'Palmitic acid', 'Stearic acid', 'Bornyl acetate', 'Eugenol', 'Methyl eugenol', 'Benzyl benzoate', 'Bicyclo elemicine', 'Caryophyllene oxide', 'Citronellal', 'Geranial', 'Geraniol', 'Germacrene B', 'Globulol', 'Hexadecanoic acid', 'Isomyristicin', 'Isoobtusilactone A', 'Myristicin', 'Obtusilactone A', 'Piperitone', 'Sabinene', 'Spathulenol', 'Trans-caryophyllene', 'Thymol', 'Viridiflorol', 'Alpha-pinene', 'Beta-pinene', 'Alpha-terpineol', 'Beta-caryophyllene', 'Alpha-humulene', 'Alpha-phellandrene', 'Gamma-terpinene', 'Delta-3-carene', 'Camphor', 'Linalool', 'Cinnamaldehyde', 'Eugenol', 'Bornyl acetate', 'Cineole', 'Borneol', 'Citronellol', 'Nerolidol', 'Caryophyllene', 'Limonene', 'Myrcene', 'P-cymene', 'Sabinene', 'Terpinen-4-ol', 'Trans-linalool oxide', 'Alpha-bisabolol', 'Alpha-cadinol', 'Alpha-muurolene', 'Alpha-selinene', 'Beta-bisabolene', 'Beta-elemene', 'Beta-selinene', 'Gamma-eudesmol', 'Delta-elemene', 'Delta-3-carene', 'Delta-cadinene', 'Anthraquinones', 'Cardiotonic glycosides', 'Cyanogenic glycosides', 'Leucoanthocyanins', 'Steroids', 'Triterpenes']
# Plant Part Used: Bark, Leaf, Fruit, Root, Stem, Twig, Wood, Heartwood, Branchlets
# Formulation: Not mentioned
# Botanic Description: Small evergreen trees and shrubs of 10–15 m tall, found in tropical rain forests at various altitudes from highland slopes to lowland forests including marshy places and on well-drained soils. Leaves are ovate-oblong and 7–18 cm long. Flowers are greenish in colour and arranged in panicles. The fruit is a 1-cm purple berry with a single seed.
# Toxicity: Some species showed toxicological effects, but overall toxicity information is limited.
# Adverse Reactions: Not mentioned
# Health Benefits: Helps in reducing cholesterol and blood sugar levels, possesses strong antifungal, antibacterial, antitermitic, larvicidal, nematicidal, and insecticidal properties.
# Nutritional Benefits: Not mentioned
# Reference: Kumar, S., Kumari, R., & Mishra, S. (2019). Pharmacological properties and their medicinal uses of Cinnamomum: a review. Journal of Pharmacy and Pharmacology, **(2019), pp. **–**. https://doi.org/10.1111/jphp.13173
# --------------------------------------
#
# ```json
# {
#   "Medicinal use(s)": "Cinnamomum plants are traditionally used for treating respiratory viruses, urinary tract infections, relieving abdominal discomfort, improving digestion, acting as antidiabetic, analgesic, and neuroprotective agents. They also serve as antiemetic, antidiarrhoeal, anti-flatulent, stimulant agents in Ayurvedic medicine and are effective against type 2 diabetes mellitus, insulin resistance, cough, cold, diarrhoea, dysentery, flatulence, rheumatism, arthritis, anaemia, abdominal pain, asthma, bronchitis, urinary infection, menstrual problems, wounds, among others.",
#   "Biological activity": "Cinnamomum species exhibit antibacterial, antidiabetic, antioxidant, anti-inflammatory, anticancer, neuroprotective, astringent, warming stimulant, carminative, blood purifier, digestive, antiseptic, antifungal, antiviral, cholesterol-reducing, and immunomodulatory properties. These effects are mediated through various mechanisms such as inhibiting bacterial growth, stimulating insulin secretion, scavenging free radicals, reducing inflammation by inhibiting NF-κB, inducing apoptosis in cancer cells, and protecting neurons from oxidative stress.",
#   "Dose": [
#     "1 g/day to 6 g/day",
#     "50 mg/day to 200 mg/day (cinnamon oil)",
#     "1.5 g/day (PCOS patients)",
#     "3 g/day (type 2 diabetic patients)"
#   ],
#   "Phytochemicals": [
#     "cinnamaldehyde",
#     "eugenol",
#     "trans-cinnamyl acetate",
#     "benzaldehyde",
#     "linalool",
#     "catechin",
#     "procyanidins",
#     "cinnamic acid",
#     "β-sitosterol",
#     "flavanol glucosides",
#     "coumarin",
#     "protocatechuic acid",
#     "vanillic acid",
#     "syringic acid",
#     "butanolides",
#     "terpenoids",
#     "lignans",
#     "diterpenoids",
#     "phenolic acids",
#     "cinncassiols",
#     "cinnzeylanol",
#     "cinnzeylanine",
#     "anhydrocinnzeylanol",
#     "anhydrocinnzeylanin",
#     "benzyl isoquinoline alkaloids",
#     "pentacyclic diterpenes",
#     "acetyl derivative",
#     "mannitol",
#     "xylose",
#     "arabinose",
#     "xylanose",
#     "glucose",
#     "mucilage",
#     "polysaccharides",
#     "subamolide D",
#     "subamolide E",
#     "subamolide B",
#     "subamolide A",
#     "apigenin",
#     "kaempferol",
#     "quercetin",
#     "Aldehydes",
#     "Acetate",
#     "Alcohol",
#     "Terpinenes",
#     "Flavonoids",
#     "Coumarins",
#     "Phenols",
#     "Saponins",
#     "Tannins",
#     "Carboxylic acid",
#     "Hydrocarbons",
#     "Camphene",
#     "Spathulenol",
#     "Fatty acids",
#     "Actinodaphnine",
#     "Kaempferol glycosides",
#     "Procyanidins",
#     "Catechins",
#     "Safrole",
#     "Methyl eugenol",
#     "Polysaccharides",
#     "Dehydrosulfurenic acid",
#     "15a-acetyldehydrosulfurenic acid",
#     "Benzoic acid",
#     "Hexadecanoic acid",
#     "Octadecanoic acid",
#     "Palmitic acid",
#     "Stearic acid",
#     "Bornyl acetate",
#     "Eugenol",
#     "Methyl eugenol",
#     "Benzyl benzoate",
#     "Bicyclo elemicine",
#     "Caryophyllene oxide",
#     "Citronellal",
#     "Geranial",
#     "Geraniol",
#     "Germacrene B",
#     "Globulol",
#     "Hexadecanoic acid",
#     "Isomyristicin",
#     "Isoobtusilactone A",
#     "Myristicin",
#     "Obtusilactone A",
#     "Piperitone",
#     "Sabinene",
#     "Spathulenol",
#     "Trans-caryophyllene",
#     "Thymol",
#     "Viridiflorol",
#     "Alpha-pinene",
#     "Beta-pinene",
#     "Alpha-terpineol",
#     "Beta-caryophyllene",
#     "Alpha-humulene",
#     "Alpha-phellandrene",
#     "Gamma-terpinene",
#     "Delta-3-carene",
#     "Camphor",
#     "Linalool",
#     "Cineole",
#     "Borneol",
#     "Citronellol",
#     "Nerolidol",
#     "Caryophyllene",
#     "Limonene",
#     "Myrcene",
#     "P-cymene",
#     "Sabinene",
#     "Terpinen-4-ol",
#     "Trans-linalool oxide",
#     "Alpha-bisabolol",
#     "Alpha-cadinol",
#     "Alpha-muurolene",
#     "Alpha-selinene",
#     "Beta-bisabolene",
#     "Beta-elemene",
#     "Beta-selinene",
#     "Gamma-eudesmol",
#     "Delta-elemene",
#     "Delta-3-carene",
#     "Delta-cadinene",
#     "Anthraquinones",
#     "Cardiotonic glycosides",
#     "Cyanogenic glycosides",
#     "Leucoanthocyanins",
#     "Steroids",
#     "Triterpenes"
#   ],
#   "Plant part used": [
#     "Bark",
#     "Leaf",
#     "Root bark",
#     "Fruits",
#     "Buds",
#     "Flowers",
#     "Stem",
#     "Twig",
#     "Root",
#     "Wood",
#     "Heartwood",
#     "Branchlets"
#   ],
#   "Formulation": [
#     "Essential oils",
#     "Aqueous extracts",
#     "Methanol extracts",
#     "Ethanol extracts",
#     "Chloroform extracts",
#     "Capsules",
#     "Tablets",
#     "Powder"
#   ],
#   "Botanic description": "Small evergreen trees and shrubs of 10–15 m tall, found in tropical rain forests at various altitudes from highland slopes to lowland forests including marshy places and on well-drained soils. Leaves are ovate-oblong and 7–18 cm long. Flowers are greenish in colour and arranged in panicles. The fruit is a 1-cm purple berry with a single seed.",
#   "Toxicity": "Coumarin found in cinnamon can negatively influence the liver, and high levels of cinnamaldehyde might correlate with liver damage and increased risk of cancer. When consumed in excess, cinnamon can cause respiratory distress, increase pulse rate, sweating process, depressive states, aggravation of rosacea symptoms, and increased risk of oral cancer. Some species showed toxicological effects, but overall toxicity information is limited.",
#   "Adverse reactions": "Gastrointestinal problems, dermatitis, steatites, allergic reactions, low blood sugar, mouth sores, breathing problems, interactions with certain medications like statins, acetaminophen, amiodarone, carbamazepine, medicines treating fungal infections, methotrexate, and methyldopa.",
#   "Health benefits": "Cinnamomum plants promote human health by providing antibacterial, antidiabetic, antioxidant, anti-inflammatory, anticancer, and neuroprotective benefits. They help reduce cholesterol and blood sugar levels, possess strong antifungal, antibacterial, antitermitic, larvicidal, nematicidal, and insecticidal properties, and can be consumed daily in diets without harmful effects, serving as disease-preventive agents.",
#   "Nutritional benefits": "Cinnamon is a source of iron, calcium, manganese, and dietary fiber. It also has properties that stimulate collagen synthesis and inhibit osteoclastogenesis, which could be beneficial for skin anti-aging treatments and bone health respectively.",
#   "References": [
#     "Shariﬁ-Rad, J., Dey, A., Koirala, N., Shaheen, S., El Omari, N., Salehi, B., et al. (2021). Cinnamomum Species: Bridging Phytochemistry Knowledge, Pharmacological Properties and Toxicological Safety for Health Beneﬁts. Frontiers in Pharmacology, 12, Article 600139. https://doi.org/10.3389/fphar.2021.600139",
#     "Kumar, S., Kumari, R., & Mishra, S. (2019). Pharmacological properties and their medicinal uses of Cinnamomum: a review. Journal of Pharmacy and Pharmacology, **(2019), pp. **–**. https://doi.org/10.1111/jphp.13173"
#   ]
# }
# ```
# 1
# Medicinal Uses: The Piper species are used worldwide in traditional medicine to treat several diseases such as urological problems, skin, liver, stomach ailments, for wound healing, and as antipyretic and anti-inflammatory agents. They are also used as natural antioxidants and antimicrobial agents in food preservation.
# Biological Activity: Piper species possess strong antioxidant activity compared to synthetic antioxidants and demonstrate antibacterial and antifungal activities against human pathogens. Additionally, they have therapeutic and preventive potential against chronic disorders including cancer, neurodegenerative diseases, diabetes, cardiovascular diseases, etc., through their antiproliferative, anti-inflammatory, and neuropharmacological properties.
# Dose: Not mentioned
# Phytochemicals: ['Piperine', 'Piplartine', 'Flavokawain A', 'Flavokawain B', 'Chavibetol', 'Eugenol', 'Safrole', 'Caryophyllene oxide', 'Bicyclogermacrene', 'Germacrene D', 'β-Caryophyllene', 'α-Humulene', 'δ-Cadinene', 'Camphor', 'Limonene', 'Myristicin', 'Elemicin']
# Plant Part Used: ['Fruits', 'Seeds', 'Leaves', 'Roots', 'Stems', 'Aerial parts', 'Inﬂorescences']
# Formulation: Not mentioned
# Botanic Description: Not mentioned
# Toxicity: Some Piper species have been associated with hepatotoxicity (e.g., kava extracts), but most studies suggest that they are generally safe when used appropriately.
# Adverse Reactions: Rare adverse effects were reported in clinical trials involving kava extracts; no significant adverse reactions were noted for other Piper species.
# Health Benefits: Piper species provide health benefits by enhancing digestion, reducing inflammation, improving memory performance, protecting against neurodegenerative diseases, alleviating anxiety, and treating various infections.
# Nutritional Benefits: Not mentioned
# Reference: Salehi, B., Zakaria, Z.A., Gyawali, R., Ibrahim, S.A., Rajkovic, J., Shinwari, Z.K., ... & Setzer, W.N. (2019). Piper Species: A Comprehensive Review on Their Phytochemistry, Biological Activities and Applications. Molecules, 24(7), 1364. https://doi.org/10.3390/molecules24071364
# --------------------------------------
# Medicinal Uses: The paper discusses the traditional uses of P. nigrum for treating menstrual disorders, ear-nose-throat problems, gastrointestinal issues, skin diseases, fever, jaundice, snake bites, and more. It also highlights its ethnoveterinary applications for livestock, including treatments for gastrointestinal disorders, coughs, colds, and skin diseases.
# Biological Activity: P. nigrum exhibits antimicrobial, antioxidant, anticancer, analgesic, anticonvulsant, neuroprotective, hypoglycemic, hypolipidemic, and anti-inflammatory activities. These effects are attributed to compounds such as piperine, piperic acid, (-)-kusunokinin, and others.
# Dose: Dosages vary depending on the preparation method and intended use. For example, piperine doses range from 5 mg/kg to 70 mg/kg in animal studies. Traditional uses involve varying amounts of powdered seeds, fruits, or decoctions, often administered orally.
# Phytochemicals: Key phytochemicals include piperine, piperic acid, pellitorine, piperlonguminine, piperamide, piperettine, (-)-kusunokinin, alkaloids, glycosides, terpenoids, steroids, flavonoids, tannins, anthraquinones, and sesquiterpenes.
# Plant Part Used: Seeds, fruits, leaves, and roots are commonly used. The seeds and fruits are most frequently utilized in traditional medicine, often ground into powder or used in decoctions.
# Formulation: Formulations include powders, pills, tablets, pastes, decoctions, infusions, and essential oils. Some formulations combine P. nigrum with other herbs or spices.
# Botanic Description: Not mentioned
# Toxicity: Piperine can be toxic at high doses. Intraperitoneal administration of 75 mg/kg caused mortality in mice within 24 hours. Acute toxicity studies indicate LD50 values ranging from 15.1 mg/kg (intravenous) to 514 mg/kg (oral gavage) in rodents.
# Adverse Reactions: High doses of piperine may cause irritation, drowsiness, and paralysis in animals. No specific adverse reactions in humans are detailed.
# Health Benefits: Health benefits include improved antioxidant status, reduced inflammation, enhanced cognitive function, alleviation of pain, regulation of blood sugar levels, lipid management, and potential anticancer effects.
# Nutritional Benefits: Not mentioned
# Reference: Takooree, H., Aumeeruddy, M. Z., Rengasamy, K. R. R., Venugopala, K. N., Jeewon, R., Zengin, G., & Mahoomodally, M. F. (2019). A systematic review on black pepper (Piper nigrum L.): From folk uses to pharmacological applications. Critical Reviews in Food Science and Nutrition, 1-34. https://doi.org/10.1080/10408398.2019.1565489
# --------------------------------------
# Medicinal Uses: Used to treat gastrointestinal disorders, malaria, respiratory diseases, cold and cough, skin cancer, scabies, nerve pain, peptic ulcers, asthma, antibacterial activity, antioxidant property, enhancing bioavailability of other herbs, improving cognitive functions, and treating vitiligo.
# Biological Activity: Anti-apoptotic, Anti-microbial, Anti-pyretic, Anti-analgesics, Anti-tumor, Anti-depressant, Anti-inflammatory, Anti-arthritic, Anti-thyroid, Anti-platelet, Anti-fungal, Anti-diarrheal, Immunomodulatory, Larvicidal activity, Antihypertensive, Antioxidant, Antitumor, Anti-asthmatics, Hepato-protective, Anxiolytic, Insecticidal, Anti-spermatogenic, Anti-Colon toxin, Anti-metastatic, Anti-spasmodic, Pesticidal.
# Dose: Not mentioned
# Phytochemicals: Piperine, β-Caryophyllene, Nerolidol, Sesquiterpenes
# Plant Part Used: Fruit (dried unripe berries), also referred to as peppercorn
# Formulation: Not mentioned
# Botanic Description: The plant produces small spherical green berries that reach a bright red when fully ripe. The dried fruit is approximately 4 mm in diameter after drying and is almost spherical in shape. Each drupe grows into a single fruit.
# Toxicity: Not mentioned
# Adverse Reactions: Not mentioned
# Health Benefits: Aids in weight loss, treats sinus, asthma, and nasal congestion, reduces the risk of cancer, heart and liver ailments, improves digestion, helps with respiratory relief, has antibacterial and antioxidant properties, enhances bioavailability, improves cognitive functions, and is beneficial for peptic ulcers and asthma treatment.
# Nutritional Benefits: Rich source of minerals like manganese, copper, calcium, phosphorus, iron, potassium, and vitamins like riboflavin, vitamin C, K, and B6. Contains dietary fiber, protein, and carbohydrates.
# Reference: Shukla, R., Rai, N., Singhai, M., & Singhai, A. K. (2018). A magical medicinal fruit of Piper nigrum. World Journal of Pharmaceutical Research, 7(8), 418-425. https://doi.org/10.20959/wjpr20188-11748
# --------------------------------------
# Medicinal Uses: The fruits of Piper nigrum are used to produce white and green peppers. It is used as a medicinal agent, preservative, and in perfumery. It contains piperine, which exhibits diverse pharmacological activities such as antihypertensive, antiplatelet, antioxidant, antitumor, anti-asthmatic, analgesic, anti-inflammatory, anti-diarrheal, antispasmodic, antidepressant, hepato-protective, immunomodulatory, antibacterial, antifungal, etc.
# Biological Activity: Piper nigrum and its active constituent piperine exhibit various biological activities including antimicrobial, antioxidant, anticancer, anti-inflammatory, hepatoprotective, anti-diarrheal, digestive, antidepressant, immunomodulatory, anticonvulsant, analgesic, and bioavailability-enhancing effects.
# Dose: Various doses were mentioned: 50 mg/kg body weight for piperine in rats; 75, 150, 300 mg/kg po for aqueous black pepper extract in mice; 30, 50, 70 mg/kg i.p. for piperine in mice; 20 mg% dietary piperine in rats.
# Phytochemicals: Piperine, pipene, piperamide, piperamine, flavonoids, phenolic contents, alkaloids, amides, steroids, lignans, neolignans, terpenes, chalcones, Brachyamide B, Dihydro-pipericide, N-Eicosadienoyl-pereridine, N-trans-Feruloyltryamine, N-Formylpiperidine, Guineensine, pentadienoyl as piperidine, Nisobuty- ldecadienamid, isobutyl-eicosadienamide, Tricholein, Trichostachine, isobutyl-eicosatrienamide, Isobutyl-octadienamide, Piperettine, Pipericide, Piperolein B, Sarmentine, Sarmentosine, Retrofractamide A.
# Plant Part Used: Fruits (dried unripe fruits known as peppercorns), seeds.
# Formulation: Not mentioned.
# Botanic Description: Piper nigrum is a flowering woody perennial climbing vine with heart-shaped alternate leaves (5-10 cm long and 3-6 cm across). The flowers are small, monoecious, and borne on pendulous spikes at the leaf nodes. The fruits are drupes, small (3-4 mm in diameter), and the dried unripe fruits are called peppercorns.
# Toxicity: Not mentioned.
# Adverse Reactions: Not mentioned.
# Health Benefits: Piper nigrum and piperine have been shown to improve memory, decrease oxidative stress, protect against cancer, reduce inflammation, enhance digestion, and exhibit antidepressant and analgesic effects.
# Nutritional Benefits: Piperine enhances the bioavailability of nutrients like beta-carotene, coenzyme Q10, curcumin, gallic acid, tiferron, and resveratrol by inhibiting metabolizing enzymes.
# Reference: Damanhouri, Z. A., & Ahmad, A. (2014). A Review on Therapeutic Potential of Piper nigrum L. (Black Pepper): The King of Spices. Medicinal & Aromatic Plants, 3(3), 161. https://doi.org/10.4172/2167-0412.1000161
# --------------------------------------
# Medicinal Uses: Piperine is used for its antiproliferative, antitumor, antiangiogenesis, antioxidant, antidiabetic, anti-obesity, cardioprotective, antimicrobial, anti-aging, and immunomodulatory effects. It is also employed in traditional medicine as an antiseptic, digestion improvement agent, diuretic, antibacterial, and insecticidal compound.
# Biological Activity: Piperine exhibits numerous pharmacological activities such as antioxidant, antitumor, antihypertensive, anti-asthmatics, analgesic, antipyretic, anti-diarrheal, anti-inflammatory, anxiolytic, antispasmodic, hepatoprotective, antidepressant, antibacterial, immunomodulatory, antifungal, antiapoptotic, anti-thyroid, antimutagenic, antimetastatic, and anti-spermatogenic properties. It also inhibits various metabolizing enzymes, boosting cognitive actions and fertility.
# Dose: The dosage varies depending on the application. For example, piperine was administered at doses ranging from 5 mg/kg to 330 mg/kg body weight in experimental studies. Specific dosages include: 170 mg/kg (oral), 85 mg/kg (intraperitoneal), 20 mg/kg (anti-diabetic effect), and 30 mg/kg (anti-obesity).
# Phytochemicals: Piperine, isopiperine, isochavicine, chavicine, flavonoids, phenolics, amides, alkaloids, steroids, neolignans, lignans, chalcones, terpenes
# Plant Part Used: Fruit, spikes, roots, stem, leaf
# Formulation: Piperine has been formulated as nanoparticles, micelles, solid lipid nanoparticles, thin-film hydration nanoparticles, zein-carrageenan core-shell nanoparticles, and mixed micelles with Soluplus/TPGS for enhanced bioavailability and therapeutic efficacy.
# Botanic Description: Not mentioned
# Toxicity: Piperine is generally considered safe within normal dietary intake levels (NOAEL: 5 mg/kg/day). However, subacute toxicity tests indicate it may be toxic at doses above 100 mg/kg body weight. High doses can cause liver damage, reproductive toxicity, and genotoxicity in vitro but not in vivo. It is non-genotoxic under normal conditions.
# Adverse Reactions: High doses of piperine may lead to irritant effects, reduced serum protein levels, elevated AST and ALP levels, reproductive dysfunction, and thymic apoptosis. It may also suppress B-lymphocyte mitogenic response and decrease primary antibody levels in serum at higher doses.
# Health Benefits: Piperine offers health benefits such as anticancer, antidiabetic, anti-obesity, cardioprotective, anti-aging, antimicrobial, anti-allergic, immunomodulatory, and anti-inflammatory effects. It also protects against neurodegenerative diseases and improves fertility.
# Nutritional Benefits: Not mentioned
# Reference: Haq, I.-U., Imran, M., Nadeem, M., Tufail, T., Gondal, T. A., & Mubarak, M. S. (2021). Piperine: A review of its biological effects. Phytotherapy Research, 35, 680–700. https://doi.org/10.1002/ptr.6855
# --------------------------------------
#
# ```json
# {
#   "Medicinal use(s)": "Piper species, including Piper nigrum, are used worldwide in traditional medicine for treating a wide range of conditions such as gastrointestinal disorders, malaria, respiratory diseases, urological problems, skin ailments, liver and stomach issues, wound healing, menstrual disorders, ear-nose-throat problems, fever, jaundice, snake bites, cold and cough, asthma, antibacterial activity, antioxidant property, enhancing bioavailability of other herbs, improving cognitive functions, treating vitiligo, antipyretic, anti-inflammatory, and as natural antioxidants and antimicrobial agents in food preservation.",
#   "Biological activity": "Piper species exhibit strong antioxidant, antimicrobial, anticancer, analgesic, anticonvulsant, neuroprotective, hypoglycemic, hypolipidemic, anti-inflammatory, anti-apoptotic, anti-microbial, anti-pyretic, anti-analgesic, anti-tumor, anti-depressant, anti-arthritic, anti-thyroid, anti-platelet, anti-fungal, anti-diarrheal, immunomodulatory, larvicidal, antihypertensive, hepato-protective, anxiolytic, insecticidal, anti-spermatogenic, anti-colon toxin, anti-metastatic, anti-spasmodic, pesticidal, and bioavailability-enhancing effects. These activities are attributed to compounds like piperine, piperic acid, (-)-kusunokinin, and others.",
#   "Dose": [
#     "5 mg/kg to 70 mg/kg (piperine in animal studies)",
#     "75, 150, 300 mg/kg po (aqueous black pepper extract in mice)",
#     "30, 50, 70 mg/kg i.p. (piperine in mice)",
#     "20 mg% dietary piperine in rats",
#     "50 mg/kg body weight (piperine in rats)",
#     "170 mg/kg (oral), 85 mg/kg (intraperitoneal), 20 mg/kg (anti-diabetic effect), 30 mg/kg (anti-obesity)"
#   ],
#   "Phytochemicals": [
#     "Piperine",
#     "Piplartine",
#     "Flavokawain A",
#     "Flavokawain B",
#     "Chavibetol",
#     "Eugenol",
#     "Safrole",
#     "Caryophyllene oxide",
#     "Bicyclogermacrene",
#     "Germacrene D",
#     "β-Caryophyllene",
#     "α-Humulene",
#     "δ-Cadinene",
#     "Camphor",
#     "Limonene",
#     "Myristicin",
#     "Elemicin",
#     "Piperic acid",
#     "Pellitorine",
#     "Piperlonguminine",
#     "Piperamide",
#     "Piperettine",
#     "(-)-kusunokinin",
#     "Alkaloids",
#     "Glycosides",
#     "Terpenoids",
#     "Steroids",
#     "Flavonoids",
#     "Tannins",
#     "Anthraquinones",
#     "Sesquiterpenes",
#     "Nerolidol",
#     "Brachyamide B",
#     "Dihydro-pipericide",
#     "N-Eicosadienoyl-pereridine",
#     "N-trans-Feruloyltryamine",
#     "N-Formylpiperidine",
#     "Guineensine",
#     "Pentadienoyl as piperidine",
#     "Nisobuty- ldecadienamid",
#     "Isobutyl-eicosadienamide",
#     "Tricholein",
#     "Trichostachine",
#     "Isobutyl-eicosatrienamide",
#     "Isobutyl-octadienamide",
#     "Piperettine",
#     "Pipericide",
#     "Piperolein B",
#     "Sarmentine",
#     "Sarmentosine",
#     "Retrofractamide A",
#     "Isopiperine",
#     "Isochavicine",
#     "Chavicine",
#     "Phenolics",
#     "Amides",
#     "Neolignans",
#     "Lignans",
#     "Chalcones",
#     "Terpenes"
#   ],
#   "Plant part used": [
#     "Fruits",
#     "Seeds",
#     "Leaves",
#     "Roots",
#     "Stems",
#     "Aerial parts",
#     "Inﬂorescences",
#     "Spikes"
#   ],
#   "Formulation": [
#     "Powders",
#     "Pills",
#     "Tablets",
#     "Pastes",
#     "Decoctions",
#     "Infusions",
#     "Essential oils",
#     "Nanoparticles",
#     "Micelles",
#     "Solid lipid nanoparticles",
#     "Thin-film hydration nanoparticles",
#     "Zein-carrageenan core-shell nanoparticles",
#     "Mixed micelles with Soluplus/TPGS"
#   ],
#   "Botanic description": "Piper nigrum is a flowering woody perennial climbing vine with heart-shaped alternate leaves (5-10 cm long and 3-6 cm across). The flowers are small, monoecious, and borne on pendulous spikes at the leaf nodes. The fruits are drupes, small (3-4 mm in diameter), and the dried unripe fruits are called peppercorns. The plant produces small spherical green berries that reach a bright red when fully ripe.",
#   "Toxicity": "Some Piper species have been associated with hepatotoxicity (e.g., kava extracts), but most studies suggest they are generally safe when used appropriately. Piperine can be toxic at high doses, with intraperitoneal administration of 75 mg/kg causing mortality in mice within 24 hours. Acute toxicity studies indicate LD50 values ranging from 15.1 mg/kg (intravenous) to 514 mg/kg (oral gavage) in rodents. Subacute toxicity tests indicate potential toxicity above 100 mg/kg body weight, with possible liver damage, reproductive toxicity, and genotoxicity in vitro but not in vivo.",
#   "Adverse reactions": "Rare adverse effects were reported in clinical trials involving kava extracts; no significant adverse reactions were noted for other Piper species. High doses of piperine may cause irritation, drowsiness, paralysis, reduced serum protein levels, elevated AST and ALP levels, reproductive dysfunction, thymic apoptosis, suppression of B-lymphocyte mitogenic response, and decreased primary antibody levels in serum at higher doses.",
#   "Health benefits": "Piper species provide health benefits by enhancing digestion, reducing inflammation, improving memory performance, protecting against neurodegenerative diseases, alleviating anxiety, treating various infections, aiding in weight loss, treating sinus, asthma, and nasal congestion, reducing the risk of cancer, heart and liver ailments, improving cognitive functions, being beneficial for peptic ulcers and asthma treatment, and exhibiting antibacterial and antioxidant properties.",
#   "Nutritional benefits": "Rich source of minerals like manganese, copper, calcium, phosphorus, iron, potassium, and vitamins like riboflavin, vitamin C, K, and B6. Contains dietary fiber, protein, carbohydrates. Piperine enhances the bioavailability of nutrients like beta-carotene, coenzyme Q10, curcumin, gallic acid, tiferron, and resveratrol by inhibiting metabolizing enzymes.",
#   "References": [
#     "Salehi, B., Zakaria, Z.A., Gyawali, R., Ibrahim, S.A., Rajkovic, J., Shinwari, Z.K., ... & Setzer, W.N. (2019). Piper Species: A Comprehensive Review on Their Phytochemistry, Biological Activities and Applications. Molecules, 24(7), 1364. https://doi.org/10.3390/molecules24071364",
#     "Takooree, H., Aumeeruddy, M. Z., Rengasamy, K. R. R., Venugopala, K. N., Jeewon, R., Zengin, G., & Mahoomodally, M. F. (2019). A systematic review on black pepper (Piper nigrum L.): From folk uses to pharmacological applications. Critical Reviews in Food Science and Nutrition, 1-34. https://doi.org/10.1080/10408398.2019.1565489",
#     "Shukla, R., Rai, N., Singhai, M., & Singhai, A. K. (2018). A magical medicinal fruit of Piper nigrum. World Journal of Pharmaceutical Research, 7(8), 418-425. https://doi.org/10.20959/wjpr20188-11748",
#     "Damanhouri, Z. A., & Ahmad, A. (2014). A Review on Therapeutic Potential of Piper nigrum L. (Black Pepper): The King of Spices. Medicinal & Aromatic Plants, 3(3), 161. https://doi.org/10.4172/2167-0412.1000161",
#     "Haq, I.-U., Imran, M., Nadeem, M., Tufail, T., Gondal, T. A., & Mubarak, M. S. (2021). Piperine: A review of its biological effects. Phytotherapy Research, 35, 680–700. https://doi.org/10.1002/ptr.6855"
#   ]
# }
# ```
# 2
# Medicinal Uses: Piperine is used for its antiproliferative, antitumor, antiangiogenesis, antioxidant, antidiabetic, anti-obesity, cardioprotective, antimicrobial, anti-aging, and immunomodulatory effects. It is also employed in traditional medicine as an antiseptic, digestion improvement agent, diuretic, antibacterial, and insecticidal compound.
# Biological Activity: Piperine exhibits numerous pharmacological activities such as antioxidant, antitumor, antihypertensive, anti-asthmatics, analgesic, antipyretic, anti-diarrheal, anti-inflammatory, anxiolytic, antispasmodic, hepatoprotective, antidepressant, antibacterial, immunomodulatory, antifungal, antiapoptotic, anti-thyroid, antimutagenic, antimetastatic, and anti-spermatogenic properties. It also inhibits various metabolizing enzymes, boosting cognitive actions and fertility.
# Dose: The dosage varies depending on the application. For example, piperine was administered at doses ranging from 5 mg/kg to 330 mg/kg body weight in experimental studies. Specific dosages include: 170 mg/kg (oral), 85 mg/kg (intraperitoneal), 20 mg/kg (anti-diabetic effect), and 30 mg/kg (anti-obesity).
# Phytochemicals: Piperine, isopiperine, isochavicine, chavicine, flavonoids, phenolics, amides, alkaloids, steroids, neolignans, lignans, chalcones, terpenes
# Plant Part Used: Fruit, spikes, roots, stem, leaf
# Formulation: Piperine has been formulated as nanoparticles, micelles, solid lipid nanoparticles, thin-film hydration nanoparticles, zein-carrageenan core-shell nanoparticles, and mixed micelles with Soluplus/TPGS for enhanced bioavailability and therapeutic efficacy.
# Botanic Description: Not mentioned
# Toxicity: Piperine is generally considered safe within normal dietary intake levels (NOAEL: 5 mg/kg/day). However, subacute toxicity tests indicate it may be toxic at doses above 100 mg/kg body weight. High doses can cause liver damage, reproductive toxicity, and genotoxicity in vitro but not in vivo. It is non-genotoxic under normal conditions.
# Adverse Reactions: High doses of piperine may lead to irritant effects, reduced serum protein levels, elevated AST and ALP levels, reproductive dysfunction, and thymic apoptosis. It may also suppress B-lymphocyte mitogenic response and decrease primary antibody levels in serum at higher doses.
# Health Benefits: Piperine offers health benefits such as anticancer, antidiabetic, anti-obesity, cardioprotective, anti-aging, antimicrobial, anti-allergic, immunomodulatory, and anti-inflammatory effects. It also protects against neurodegenerative diseases and improves fertility.
# Nutritional Benefits: Not mentioned
# Reference: Haq, I.-U., Imran, M., Nadeem, M., Tufail, T., Gondal, T. A., & Mubarak, M. S. (2021). Piperine: A review of its biological effects. Phytotherapy Research, 35, 680–700. https://doi.org/10.1002/ptr.6855
# --------------------------------------
#
# ```json
# {
#   "Medicinal use(s)": "Piperine is used for its antiproliferative, antitumor, antiangiogenesis, antioxidant, antidiabetic, anti-obesity, cardioprotective, antimicrobial, anti-aging, and immunomodulatory effects. It is also employed in traditional medicine as an antiseptic, digestion improvement agent, diuretic, antibacterial, and insecticidal compound.",
#   "Biological activity": "Piperine exhibits numerous pharmacological activities such as antioxidant, antitumor, antihypertensive, anti-asthmatics, analgesic, antipyretic, anti-diarrheal, anti-inflammatory, anxiolytic, antispasmodic, hepatoprotective, antidepressant, antibacterial, immunomodulatory, antifungal, antiapoptotic, anti-thyroid, antimutagenic, antimetastatic, and anti-spermatogenic properties. It inhibits various metabolizing enzymes, boosting cognitive actions and fertility.",
#   "Dose": [
#     "5 mg/kg to 330 mg/kg body weight",
#     "170 mg/kg (oral)",
#     "85 mg/kg (intraperitoneal)",
#     "20 mg/kg (anti-diabetic effect)",
#     "30 mg/kg (anti-obesity)"
#   ],
#   "Phytochemicals": [
#     "piperine",
#     "isopiperine",
#     "isochavicine",
#     "chavicine",
#     "flavonoids",
#     "phenolics",
#     "amides",
#     "alkaloids",
#     "steroids",
#     "neolignans",
#     "lignans",
#     "chalcones",
#     "terpenes"
#   ],
#   "Plant part used": [
#     "fruit",
#     "spikes",
#     "roots",
#     "stem",
#     "leaf"
#   ],
#   "Formulation": [
#     "nanoparticles",
#     "micelles",
#     "solid lipid nanoparticles",
#     "thin-film hydration nanoparticles",
#     "zein-carrageenan core-shell nanoparticles",
#     "mixed micelles with Soluplus/TPGS"
#   ],
#   "Botanic description": "Not mentioned",
#   "Toxicity": "Piperine is generally considered safe within normal dietary intake levels (NOAEL: 5 mg/kg/day). However, subacute toxicity tests indicate it may be toxic at doses above 100 mg/kg body weight. High doses can cause liver damage, reproductive toxicity, and genotoxicity in vitro but not in vivo. It is non-genotoxic under normal conditions.",
#   "Adverse reactions": "High doses of piperine may lead to irritant effects, reduced serum protein levels, elevated AST and ALP levels, reproductive dysfunction, and thymic apoptosis. It may also suppress B-lymphocyte mitogenic response and decrease primary antibody levels in serum at higher doses.",
#   "Health benefits": "Piperine offers health benefits such as anticancer, antidiabetic, anti-obesity, cardioprotective, anti-aging, antimicrobial, anti-allergic, immunomodulatory, and anti-inflammatory effects. It also protects against neurodegenerative diseases and improves fertility.",
#   "Nutritional benefits": "Not mentioned",
#   "References": [
#     "Haq, I.-U., Imran, M., Nadeem, M., Tufail, T., Gondal, T. A., & Mubarak, M. S. (2021). Piperine: A review of its biological effects. Phytotherapy Research, 35, 680–700. https://doi.org/10.1002/ptr.6855"
#   ]
# }
# ```
# 3
# Medicinal Uses: Used for relief of symptoms of cough associated with cold and for the symptomatic relief of localized muscle pain.
# Biological Activity: The oil has antimicrobial, antifungal, antiviral, anti-inflammatory, analgesic, antioxidant, and expectorant properties. It also influences respiratory tract fluid/ciliary beat frequency and enhances skin penetration of drugs.
# Dose: Oral: 100-200 mg, 2-5 times daily; Cutaneous: Liquid dosage forms - a few drops, 2-3 times daily; Semi-solid dosage forms (10% Eucalyptus oil) - apply a thin layer, 2-3 times daily; Inhalation: up to 3-8 drops per 250 ml boiling water, 3 times daily; Bath additive: 1.5-6 g essential oil/100 l water, 3-4 times a week.
# Phytochemicals: ['1,8-cineole', 'α-pinene', 'β-pinene', 'limonene', 'geraniol', 'camphene', 'aromadendrene', 'cuminaldehyde', 'globulol', 'pinocarveol', 'p-cymene', 'γ-terpinene', '4-terpineol', 'α-terpineol', 'viridiflorol', 'linalool', 'spathulenol', '10-epi-γ-eudesmol', 'non-volatile monoterpene glucosides conjugated with gallic acid']
# Plant Part Used: Fresh leaves or fresh terminal branchlets
# Formulation: Liquid or solid dosage forms for oral use, liquid dosage forms for inhalation or as bath additives, liquid or semi-solid dosage forms for cutaneous use.
# Botanic Description: Eucalyptus trees are evergreen with leathery oil glands covered leaves. E. globulus has ensiform or sword-shaped leaves, bluish-green in hue. E. polybractea is a small perennial tree with smooth and fibrous bark near the trunk base. E. smithii is a medium-sized tree with deeply fissured bark at the lower part and smooth white bark in the upper parts.
# Toxicity: Acute toxicity data indicate LD50 values of 4.4 g/kg for rats and 3.3 g/kg for mice. Overdose can cause CNS depression, respiratory problems, gastrointestinal symptoms, and other systemic effects. Allergic reactions may occur after topical application.
# Adverse Reactions: Nausea, vomiting, diarrhoea, allergic skin reactions, dizziness, tiredness, coordination abnormalities, ataxia, aphasia, syncope, urticaria, pustular rash, skin irritation, contact allergy, bullous eruption.
# Health Benefits: Relief of cough associated with cold, symptomatic relief of localized muscle pain, increased feeling of relaxation, increased cutaneous blood flow and skin temperature.
# Nutritional Benefits: Not mentioned
# Reference: Wiesner, J., & Hönow, R. (2014). Assessment report on Eucalytus globulus Labill., Eucalyptus polybractea R.T. Baker and/or Eucalyptus smithii R.T. Baker, aetheroleum. European Medicines Agency. https://www.ema.europa.eu/en/documents/herbal-report/assessment-report-eucalyptus-globulus-labill-eucalyptus-polybractea-r-t-baker-eucalyptus-smithii-r-t-baker-aetheroleum_en.pdf
# --------------------------------------
#
# ```json
# {
#   "Medicinal use(s)": "Used for relief of symptoms of cough associated with cold and for the symptomatic relief of localized muscle pain.",
#   "Biological activity": "The oil has antimicrobial, antifungal, antiviral, anti-inflammatory, analgesic, antioxidant, and expectorant properties. It influences respiratory tract fluid/ciliary beat frequency and enhances skin penetration of drugs.",
#   "Dose": [
#     "Oral: 100-200 mg, 2-5 times daily",
#     "Cutaneous: Liquid dosage forms - a few drops, 2-3 times daily; Semi-solid dosage forms (10% Eucalyptus oil) - apply a thin layer, 2-3 times daily",
#     "Inhalation: up to 3-8 drops per 250 ml boiling water, 3 times daily",
#     "Bath additive: 1.5-6 g essential oil/100 l water, 3-4 times a week"
#   ],
#   "Phytochemicals": [
#     "1,8-cineole",
#     "α-pinene",
#     "β-pinene",
#     "limonene",
#     "geraniol",
#     "camphene",
#     "aromadendrene",
#     "cuminaldehyde",
#     "globulol",
#     "pinocarveol",
#     "p-cymene",
#     "γ-terpinene",
#     "4-terpineol",
#     "α-terpineol",
#     "viridiflorol",
#     "linalool",
#     "spathulenol",
#     "10-epi-γ-eudesmol",
#     "non-volatile monoterpene glucosides conjugated with gallic acid"
#   ],
#   "Plant part used": ["Fresh leaves", "Fresh terminal branchlets"],
#   "Formulation": [
#     "Liquid or solid dosage forms for oral use",
#     "Liquid dosage forms for inhalation or as bath additives",
#     "Liquid or semi-solid dosage forms for cutaneous use"
#   ],
#   "Botanic description": "Eucalyptus trees are evergreen with leathery oil glands covered leaves. E. globulus has ensiform or sword-shaped leaves, bluish-green in hue. E. polybractea is a small perennial tree with smooth and fibrous bark near the trunk base. E. smithii is a medium-sized tree with deeply fissured bark at the lower part and smooth white bark in the upper parts.",
#   "Toxicity": "Acute toxicity data indicate LD50 values of 4.4 g/kg for rats and 3.3 g/kg for mice. Overdose can cause CNS depression, respiratory problems, gastrointestinal symptoms, and other systemic effects. Allergic reactions may occur after topical application.",
#   "Adverse reactions": "Nausea, vomiting, diarrhoea, allergic skin reactions, dizziness, tiredness, coordination abnormalities, ataxia, aphasia, syncope, urticaria, pustular rash, skin irritation, contact allergy, bullous eruption.",
#   "Health benefits": "Relief of cough associated with cold, symptomatic relief of localized muscle pain, increased feeling of relaxation, increased cutaneous blood flow and skin temperature.",
#   "Nutritional benefits": "Not mentioned",
#   "References": [
#     "Wiesner, J., & Hönow, R. (2014). Assessment report on Eucalytus globulus Labill., Eucalyptus polybractea R.T. Baker and/or Eucalyptus smithii R.T. Baker, aetheroleum. European Medicines Agency. https://www.ema.europa.eu/en/documents/herbal-report/assessment-report-eucalyptus-globulus-labill-eucalyptus-polybractea-r-t-baker-eucalyptus-smithii-r-t-baker-aetheroleum_en.pdf"
#   ]
# }
# ```
# 4
# Medicinal Uses: Used in traditional medicine for treating arthritis, rheumatism, stomach aches, skin rashes, alleviating dog and snake bites, increasing digestive warmth, as medication for the alleviation of edema, hemorrhoids, parasitic protozoa, leprosy, applied topically in pain disorders, neuropathy, cluster headache, migraine, psoriasis, trigeminal neuralgia, herpes zoster, treating dyspepsia, loss of appetite, flatulence, atherosclerosis, stroke, heart disease, muscle tension.
# Biological Activity: Antioxidant, antimicrobial, chemopreventive, anti-diabetic, gastroprotective, pain relief, potential role in metabolic syndrome, antihypercholesterolemic, anti-inflammatory, hypotriglyceridemic, cardiovascular protective.
# Dose: 0.5–5 g capsaicin/kg (around 50,000 mg per person), 5 g of C. frutescens decreased plasma glucose levels at 30 and 45 minutes, 1.75 mg capsaicin ingestion for 5 weeks, topical application of creams containing 0.075% or 0.025% capsaicin, single application of capsaicin 8% patch for 60 minutes, 9 mg capsaicinoids ingestion, 0.4 mg capsaicin supplement, 625 mg green tea extract and 800 mg essence of chicken, 0.01-0.02% capsaicin in the diet for 6 weeks, 0.5-1 mg/kg body weight for 14 d capsaicin.
# Phytochemicals: capsaicin, dihydrocapsaicin, nordihydrocapsaicin, homocapsaicin, homodihydrocapsaicin, nornorcapsaicin, quercetin, luteolin, apigenin, sinapoyl glycosides, feruloyl glycosides, capsiate, dihydrocapsiate, nordihydrocapsiate, carotenoids, flavonoids, phenolic acids, ascorbic acid, chrysoeriol, DING proteins, thioredoxin/apoptosis signal-regulating kinase 1 (ASK1)
# Plant Part Used: Fruit, seeds, stem
# Formulation: Creams, ointments, patches, extracts, oleoresin, powder, juice
# Botanic Description: Not mentioned
# Toxicity: Capsaicin is considered safe in normal daily intake but can cause skin irritation, eye irritation, bronchoconstriction, coughing, nausea, and loss of coordination in high doses. Exposure to capsaicinoids may result in temporary blindness, lacrimation, burning sensation, pain, and skin redness, nasal irritation, and dyspnea.
# Adverse Reactions: Topical capsaicin causes consistently higher side effects such as burning sensation lasting minutes to hours.
# Health Benefits: Antioxidant, anticancer, anti-diabetic, gastroprotective, analgesic, weight management, antihypertensive, lipid-lowering, anti-inflammatory, cardiovascular protective.
# Nutritional Benefits: Rich in vitamins C and E, provitamin A, carotenoids, phenolic compounds, minerals like calcium, phosphorus, selenium, iron, sodium, copper, potassium, fatty acids, protein, energy, carbohydrate.
# Reference: Salehi, B., Hernández-Álvarez, A. J., Contreras, M. D. M., Martorell, M., Ramírez-Alarcón, K., Melgar-Lalanne, G., ... & Sharifi-Rad, J. (2018). Potential Phytopharmacy and Food Applications of Capsicum spp.: A Comprehensive Review. Natural Product Communications, 13(11), 1543-1556.
# --------------------------------------
# Medicinal Uses: Used in traditional medicine to remedy asthma, cough, throat irritation, and other respiratory disorders. Also used as a condiment and source of vitamin C.
# Biological Activity: Antioxidant, antimicrobial, anti-inflammatory, antihypertensive, antihyperglycemic, metal-chelating, and antitumoral activities.
# Dose: Not mentioned
# ...
#     "Ethanolic extracts",
#     "Methanolic extracts",
#     "Lyophilized extracts",
#     "Infusions",
#     "Teas",
#     "Infusion",
#     "Decoction",
#     "Tincture",
#     "Plaster",
#     "Powder",
#     "Granules",
#     "Capsules",
#     "Troche",
#     "Liquid pharmaceutical preparations",
#     "Tablets",
#     "Suppositories",
#     "Extracts (ethanol, aqueous, methanol)",
#     "Polysaccharides",
#     "Glycosides",
#     "Peptides",
#     "Nanoparticles",
#     "Essential oils",
#     "Dietary supplements",
#     "Traditional formulations",
#     "Infusions",
#     "Syrups",
#     "Exosome-like nanovesicles",
#     "Carboxymethylated polysaccharides"
#   ],
#   "Botanic description": "Perennial weed with a stout taproot reaching up to 100 cm in length, large serrated leaves forming a rosette at the base, solitary yellow flower heads on upright stalks, and conical achenes with white hairy pappus for seed dispersal. Perennial herb with simple, lobed leaves forming a basal rosette, yellow to orange flower heads opening during the daytime and closing at night, borne singly on a hollow stem, producing spherical seed heads containing single-seeded fruits called achenes. Belongs to the Asteraceae family, grows in temperate and subtropical regions, thriving in low to mid-altitude areas such as hillsides, roadsides, fields, and riverbanks, with white, milky sap and blooms mid-late May with a flowering period lasting 35–45 days.",
#   "Toxicity": "Low toxicity due to absence of significant toxins or alkaloids. Intraperitoneal LD50 values for fluid herb and root extract are 28.8 and 36.6 g/kg body weight, respectively. Ethanol extracts show very low toxicity up to doses of 10 g/kg orally and 4 g/kg intraperitoneally. No significant toxicity or side effects reported; acute toxicity tests showed DL50 = 27.2 g·kg−1 body weight. Daily drinking of excessive dandelion tea may pose a potential threat to human health due to heavy metals like lead, cadmium, and nickel accumulation.",
#   "Adverse reactions": "May cause allergic contact dermatitis due to the presence of sesquiterpene lactones. Not mentioned in some sources.",
#   "Health benefits": "Improved digestion, enhanced bile secretion, reduced inflammation, antioxidant protection, potential anticancer effects, pain relief, regulation of blood sugar levels, prevention of blood clotting, promotion of gut health through prebiotic activity. Promotes liver health, reduces oxidative stress, improves lipid profiles, alleviates inflammation, enhances antioxidant capacity, protects against bacterial infections, supports bone health, exhibits potential in treating cancers like triple-negative breast cancer. Offers antioxidant, anti-inflammatory, antimicrobial, anti-tumor, hepatoprotective, hypolipidemic, anti-diabetic, anti-fatigue, immune-enhancing properties. Improves lipid metabolism, alleviates oxidative stress, prevents non-alcoholic fatty liver disease, and protects against UVB damage and cellular senescence.",
#   "Nutritional benefits": "Rich in potassium, sesquiterpenes, phenolic compounds, phytosterols, triterpenes, flavonoids, coumarins, essential oils, vitamins (A, B, C, D, E), minerals (calcium, potassium, magnesium, manganese, zinc), amino acids, proteins, trace elements, contributing to its nutritional value. Enhances nutritional value of eggs when included in hen diets.",
#   "References": [
#     "Schütz, K., Carle, R., & Schieber, A. (2006). Taraxacum—A review on its phytochemical and pharmacological profile. Journal of Ethnopharmacology, 107(3), 313–323. https://doi.org/10.1016/j.jep.2006.07.021",
#     "Fan, M.; Zhang, X.; Song, H.; Zhang, Y. Dandelion (Taraxacum Genus): A Review of Chemical Constituents and Pharmacological Effects. Molecules 2023, 28(13), 5022. https://doi.org/10.3390/molecules28135022",
#     "Yan, Q., Xing, Q., Liu, Z., Zou, Y., Liu, X., & Xia, H. (2024). The phytochemical and pharmacological profile of dandelion. Biomedicine & Pharmacotherapy, 179, 117334. https://doi.org/10.1016/j.biopha.2024.117334"
#   ]
# }
# ```
# 106
# Medicinal Uses: Used as antiemetic, antidiarrhoeal, anti-flatulent, stimulant agent in Ayurvedic medicine; cure for type 2 diabetes mellitus and insulin resistance; antimicrobial activity against various ailments such as cough, cold, diarrhoea, dysentery, flatulence, rheumatism, etc.; treatment for arthritis, anaemia, abdominal pain, asthma, bronchitis, urinary infection, menstrual problems, wounds, among others.
# Biological Activity: The plant extracts possess astringent, warming stimulant, carminative, blood purifier, digestive, antiseptic, antifungal, antiviral, antibacterial, antioxidant, anti-inflammatory, immunomodulatory properties, along with the ability to reduce cholesterol and blood sugar levels.
# Dose: Not mentioned
# Phytochemicals: ['Aldehydes', 'Acetate', 'Alcohol', 'Terpinenes', 'Flavonoids', 'Coumarins', 'Phenols', 'Saponins', 'Tannins', 'Carboxylic acid', 'Hydrocarbons', 'Camphene', 'Spathulenol', 'Fatty acids', 'Actinodaphnine', 'Butanolides', 'Kaempferol glycosides', 'Procyanidins', 'Catechins', 'Safrole', 'Methyl eugenol', 'Polysaccharides', 'Dehydrosulfurenic acid', '15a-acetyldehydrosulfurenic acid', 'Benzoic acid', 'Hexadecanoic acid', 'Octadecanoic acid', 'Palmitic acid', 'Stearic acid', 'Bornyl acetate', 'Eugenol', 'Methyl eugenol', 'Benzyl benzoate', 'Bicyclo elemicine', 'Caryophyllene oxide', 'Citronellal', 'Geranial', 'Geraniol', 'Germacrene B', 'Globulol', 'Hexadecanoic acid', 'Isomyristicin', 'Isoobtusilactone A', 'Myristicin', 'Obtusilactone A', 'Piperitone', 'Sabinene', 'Spathulenol', 'Trans-caryophyllene', 'Thymol', 'Viridiflorol', 'Alpha-pinene', 'Beta-pinene', 'Alpha-terpineol', 'Beta-caryophyllene', 'Alpha-humulene', 'Alpha-phellandrene', 'Gamma-terpinene', 'Delta-3-carene', 'Camphor', 'Linalool', 'Cinnamaldehyde', 'Eugenol', 'Bornyl acetate', 'Cineole', 'Borneol', 'Citronellol', 'Nerolidol', 'Caryophyllene', 'Limonene', 'Myrcene', 'P-cymene', 'Sabinene', 'Terpinen-4-ol', 'Trans-linalool oxide', 'Alpha-bisabolol', 'Alpha-cadinol', 'Alpha-muurolene', 'Alpha-selinene', 'Beta-bisabolene', 'Beta-elemene', 'Beta-selinene', 'Gamma-eudesmol', 'Delta-elemene', 'Delta-3-carene', 'Delta-cadinene', 'Anthraquinones', 'Cardiotonic glycosides', 'Cyanogenic glycosides', 'Leucoanthocyanins', 'Steroids', 'Triterpenes']
# Plant Part Used: Bark, Leaf, Fruit, Root, Stem, Twig, Wood, Heartwood, Branchlets
# Formulation: Not mentioned
# Botanic Description: Small evergreen trees and shrubs of 10–15 m tall, found in tropical rain forests at various altitudes from highland slopes to lowland forests including marshy places and on well-drained soils. Leaves are ovate-oblong and 7–18 cm long. Flowers are greenish in colour and arranged in panicles. The fruit is a 1-cm purple berry with a single seed.
# Toxicity: Some species showed toxicological effects, but overall toxicity information is limited.
# Adverse Reactions: Not mentioned
# Health Benefits: Helps in reducing cholesterol and blood sugar levels, possesses strong antifungal, antibacterial, antitermitic, larvicidal, nematicidal, and insecticidal properties.
# Nutritional Benefits: Not mentioned
# Reference: Kumar, S., Kumari, R., & Mishra, S. (2019). Pharmacological properties and their medicinal uses of Cinnamomum: a review. Journal of Pharmacy and Pharmacology, **(2019), pp. **–**. https://doi.org/10.1111/jphp.13173
# --------------------------------------
#
# ```json
# {
#   "Medicinal use(s)": "Used as an antiemetic, antidiarrhoeal, anti-flatulent, stimulant agent in Ayurvedic medicine. It is also used for treating type 2 diabetes mellitus and insulin resistance, microbial infections (cough, cold, diarrhoea, dysentery, flatulence, rheumatism), arthritis, anaemia, abdominal pain, asthma, bronchitis, urinary infection, menstrual problems, and wounds.",
#   "Biological activity": "The plant exhibits astringent, warming stimulant, carminative, blood purifier, digestive, antiseptic, antifungal, antiviral, antibacterial, antioxidant, anti-inflammatory, and immunomodulatory properties. It helps reduce cholesterol and blood sugar levels.",
#   "Dose": "Not mentioned",
#   "Phytochemicals": [
#     "Aldehydes", "Acetate", "Alcohol", "Terpinenes", "Flavonoids", "Coumarins", "Phenols", "Saponins", "Tannins", "Carboxylic acid", "Hydrocarbons", "Camphene", "Spathulenol", "Fatty acids", "Actinodaphnine", "Butanolides", "Kaempferol glycosides", "Procyanidins", "Catechins", "Safrole", "Methyl eugenol", "Polysaccharides", "Dehydrosulfurenic acid", "15a-acetyldehydrosulfurenic acid", "Benzoic acid", "Hexadecanoic acid", "Octadecanoic acid", "Palmitic acid", "Stearic acid", "Bornyl acetate", "Eugenol", "Methyl eugenol", "Benzyl benzoate", "Bicyclo elemicine", "Caryophyllene oxide", "Citronellal", "Geranial", "Geraniol", "Germacrene B", "Globulol", "Hexadecanoic acid", "Isomyristicin", "Isoobtusilactone A", "Myristicin", "Obtusilactone A", "Piperitone", "Sabinene", "Spathulenol", "Trans-caryophyllene", "Thymol", "Viridiflorol", "Alpha-pinene", "Beta-pinene", "Alpha-terpineol", "Beta-caryophyllene", "Alpha-humulene", "Alpha-phellandrene", "Gamma-terpinene", "Delta-3-carene", "Camphor", "Linalool", "Cinnamaldehyde", "Eugenol", "Bornyl acetate", "Cineole", "Borneol", "Citronellol", "Nerolidol", "Caryophyllene", "Limonene", "Myrcene", "P-cymene", "Sabinene", "Terpinen-4-ol", "Trans-linalool oxide", "Alpha-bisabolol", "Alpha-cadinol", "Alpha-muurolene", "Alpha-selinene", "Beta-bisabolene", "Beta-elemene", "Beta-selinene", "Gamma-eudesmol", "Delta-elemene", "Delta-3-carene", "Delta-cadinene", "Anthraquinones", "Cardiotonic glycosides", "Cyanogenic glycosides", "Leucoanthocyanins", "Steroids", "Triterpenes"
#   ],
#   "Plant part used": ["Bark", "Leaf", "Fruit", "Root", "Stem", "Twig", "Wood", "Heartwood", "Branchlets"],
#   "Formulation": "Not mentioned",
#   "Botanic description": "Small evergreen trees or shrubs, 10–15 m tall, found in tropical rainforests at various altitudes, including highland slopes, lowland forests, marshy places, and well-drained soils. Leaves are ovate-oblong, 7–18 cm long. Flowers are greenish and arranged in panicles. The fruit is a 1-cm purple berry with a single seed.",
#   "Toxicity": "Some species showed toxicological effects, but overall toxicity information is limited.",
#   "Adverse reactions": "Not mentioned",
#   "Health benefits": "Reduces cholesterol and blood sugar levels. Possesses strong antifungal, antibacterial, antitermitic, larvicidal, nematicidal, and insecticidal properties.",
#   "Nutritional benefits": "Not mentioned",
#   "References": [
#     "Kumar, S., Kumari, R., & Mishra, S. (2019). Pharmacological properties and their medicinal uses of Cinnamomum: a review. Journal of Pharmacy and Pharmacology, (2019), pp. –. https://doi.org/10.1111/jphp.13173"
#   ]
# }
# ```
# 107
# Medicinal Uses: The Ocimum species have been traditionally used for treating various ailments such as digestive disorders, respiratory issues, sedative effects, coughs, bronchitis, immune disorders, toothaches, dysentery, headaches, coughs, diarrhea, constipation, warts, kidney damage, high blood pressure, stomach aches, fever, malaria, skin diseases, arthritis, bronchial asthma, insect bites, antiseptic purposes, and more.
# Biological Activity: The Ocimum species exhibit antioxidant, antifungal, antimicrobial, anti-insecticide, larvicidal, gastric cytoprotective antiulcer, anticancer, anti-inflammatory, antiviral, antidiabetic, analgesic, cardioprotective, and immunomodulatory properties. They also possess antibacterial activity against both Gram-positive and Gram-negative bacteria.
# Dose: Not mentioned
# Phytochemicals: ['Alkaloids', 'Flavonoids', 'Phenolic compounds', 'Tannins', 'Terpenoids', 'Saponins', 'Steroids', 'Glicosides', 'Organic acids', 'Fatty acids', 'Ketones', 'Enone', 'Aldehydes', 'Esters', 'Monoterpenoids', 'Sesquiterpenoids', 'Triterpenoids', 'Phenylpropanoids']
# Plant Part Used: Leaves, flowers, stems, fruits, aerial parts, seeds
# Formulation: Decoction, infusion, essential oils, extracts (ethyl acetate, methanol, ethanol, hexane), juice
# Botanic Description: Descriptions vary by species but generally include plants with heights ranging from 15 cm to several meters, having sub-rectangular striated branches, intact or faintly serrated leaves, lanceolate ellipse leaf shapes, glandular spots, glabrous surfaces, pink, white, or purplish flowers, and elongated circle-shaped fruits. Some species have aromatic leaves and are known for their essential oil components.
# Toxicity: Not mentioned
# Adverse Reactions: Not mentioned
# Health Benefits: These plants provide benefits such as anticancer, antispasmodic, antifertility, antimicrobial, anti-inflammatory, antioxidant, antifungal, analgesic, antidiabetic, cardio protective, adaptogenic, antiemetic, hepatoprotective, and nutritional support including vitamins C, A, minerals like zinc, iron, calcium, and protein content.
# Nutritional Benefits: Some Ocimum species contain vitamins C, A, minerals such as zinc, iron, calcium, and protein. For example, O. sanctum contains 4.2 g protein, 0.5 g fat, 25 mg carbohydrates, 287 mg phosphorus, 25 mg calcium, vitamin C per 100 g, and 15.1 mg iron.
# Reference: Dharsono, H. D. A., Putri, S. A., Kurnia, D., Dudi, D., & Satari, M. H. (2022). Ocimum Species: A Review on Chemical Constituents and Antibacterial Activity. Molecules, 27(19), 6350. https://doi.org/10.3390/molecules27196350
# --------------------------------------
#
# ```json
# {
#   "Medicinal use(s)": "The Ocimum species are traditionally used for treating digestive disorders, respiratory issues, sedative effects, coughs, bronchitis, immune disorders, toothaches, dysentery, headaches, diarrhea, constipation, warts, kidney damage, high blood pressure, stomach aches, fever, malaria, skin diseases, arthritis, bronchial asthma, insect bites, and antiseptic purposes.",
#   "Biological activity": "Ocimum species exhibit antioxidant, antifungal, antimicrobial, anti-insecticide, larvicidal, gastric cytoprotective antiulcer, anticancer, anti-inflammatory, antiviral, antidiabetic, analgesic, cardioprotective, and immunomodulatory properties. They also possess antibacterial activity against both Gram-positive and Gram-negative bacteria.",
#   "Dose": "Not mentioned",
#   "Phytochemicals": ["Alkaloids", "Flavonoids", "Phenolic compounds", "Tannins", "Terpenoids", "Saponins", "Steroids", "Glicosides", "Organic acids", "Fatty acids", "Ketones", "Enone", "Aldehydes", "Esters", "Monoterpenoids", "Sesquiterpenoids", "Triterpenoids", "Phenylpropanoids"],
#   "Plant part used": ["Leaves", "flowers", "stems", "fruits", "aerial parts", "seeds"],
#   "Formulation": ["Decoction", "infusion", "essential oils", "extracts (ethyl acetate, methanol, ethanol, hexane)", "juice"],
#   "Botanic description": "Ocimum species generally grow from 15 cm to several meters tall with sub-rectangular striated branches, intact or faintly serrated leaves in lanceolate ellipse shapes, glandular spots, glabrous surfaces, pink, white, or purplish flowers, and elongated circle-shaped fruits. Some species have aromatic leaves rich in essential oil components.",
#   "Toxicity": "Not mentioned",
#   "Adverse reactions": "Not mentioned",
#   "Health benefits": "Ocimum species provide anticancer, antispasmodic, antifertility, antimicrobial, anti-inflammatory, antioxidant, antifungal, analgesic, antidiabetic, cardio protective, adaptogenic, antiemetic, hepatoprotective, and nutritional support including vitamins C, A, minerals like zinc, iron, calcium, and protein content.",
#   "Nutritional benefits": "Some Ocimum species contain vitamins C, A, minerals such as zinc, iron, calcium, and protein. For example, O. sanctum contains 4.2 g protein, 0.5 g fat, 25 mg carbohydrates, 287 mg phosphorus, 25 mg calcium, vitamin C per 100 g, and 15.1 mg iron.",
#   "References": [
#     "Dharsono, H. D. A., Putri, S. A., Kurnia, D., Dudi, D., & Satari, M. H. (2022). Ocimum Species: A Review on Chemical Constituents and Antibacterial Activity. Molecules, 27(19), 6350. https://doi.org/10.3390/molecules27196350"
#   ]
# }
# ```
# 108

# %%
print(0)
# Out:
# 0
