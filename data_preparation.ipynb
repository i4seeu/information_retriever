# %%
import pandas as pd
import os
from pdfminer.high_level import extract_text

# %%
def extract_text_from_pdf(pdf_path):
    #extract pdf from pdf file
    text  = extract_text(pdf_path)
    return text

# %%
import fitz
def extract_text_from_pdf2(pdf_path):
    # Open the PDF file
    doc = fitz.open(pdf_path)
    text = ""

    # Iterate through each page
    for page_num in range(len(doc)):
        page = doc.load_page(page_num)  # Load the page
        text += page.get_text()  # Extract text from the page

    return text

# %%
system_prompt = """ 
You are an expert in reading and understanding research papers, You are given a research paper on herbal medicine. Extract the following information based on the structure below. If a section is not present, mention "Not mentioned" or "Not applicable."

1. Title: Extract the full title of the research paper.
2. Authors: List all the authors of the paper, separated by commas.
3. Year: Provide the year of publication. If not available, use "Not available."
4. Scientific name of Medicinal plant: Extract all scientific names of the medicinal plants mentioned in the paper. If multiple plants are mentioned, list them all.
5. Medicinal use: Extract any medicinal use i.e the application of herbs, or medical plants, to prevent, diagnose, treat, or manage diseases and health conditions.If not available, use "Not mentioned."
6. Biological activity: Describe the biological activities of the medicinal plants in detail. If the paper does not cover biological activities, mention "Not mentioned."
7. Dose: Extract any information related to dosage, including amounts and units. If the paper does not mention dosages, use "Not mentioned."
8. Phytochemicals: List all phytochemicals present in the medicinal plants,that is mentioned in the paper only. If not available, use "Not mentioned."
9. Plant part used: Describe the part of the plant used for medicinal purposes,that is mentioned in the paper only. If not available, use "Not mentioned."
10. Formulation: Extract details about the formulation of the medicinal plants (e.g., tablets, capsules, extracts),that is mentioned in the paper only. If not available, use "Not mentioned."
11. Botanic description: Detailed physical characteristics of a plant, including its structure, appearance, and growth habits. if available. Otherwise, mention "Not mentioned."
12. Toxicity: Extract any information related to the toxicity of the medicinal plants,that is mentioned in the paper only. If no toxicity information is available, mention "Not mentioned."
13. Adverse reactions: List any reported adverse reactions,that is mentioned in the paper only. If none are mentioned, use "Not mentioned."
14. Health Benefits: Describe any health benefits offered by the medicinal plants, that is mentioned in the paper only. If no health benefits are mentioned, use "Not mentioned."
15. Nutritional benefits: Extract any nutritional benefits provided by the medicinal plants,that is mentioned in the paper only. If not applicable, mention "Not mentioned."
16. Reference: Extract the relevant citation information from a provided research paper, article, or academic text (such as title, author(s), year of publication, journal name, volume, issue, page numbers, and DOI), and format it according to the APA style (7th edition). The output should be a properly formatted APA reference.. If not applicable, mention "Not mentioned."

Edge cases to consider:
- If the paper mentions multiple plants, ensure all relevant information is extracted for each plant.
- If certain sections (e.g., adverse reactions, toxicity) are missing from the paper, ensure the output reflects this absence (e.g., "Not mentioned").
- Ensure correct units for dosages are extracted, including when multiple dosages are provided.
- When extracting formulation, provide details on the preparation method, if available.
- Do not change the title, write as you have extracted it from the paper but change the format to title case.
- On other columns  Biological activity, Dose, Formulation, Botanic description, Toxicity, Adverse reactions, Health Benefits, Nutritional benefits, do not just extract but summarize the information and provide definitions where necessary."
- For all the columns provided , please make sure you are using only information from the extracted paper.
"""

# %%
pdf_folder = 'dataextraction'
filename_text_dict = {}
for pdf_file in os.listdir(pdf_folder):
    if pdf_file.endswith('.pdf'):
        pdf_path = os.path.join(pdf_folder,pdf_file)
        try:
            pdf_text = extract_text_from_pdf2(pdf_path)
        except:
            print("error with the file")
        #pdf_text = extract_text_from_pdf(pdf_path)
        #combined_input = prompt  + pdf_text
        filename_text_dict[pdf_file] = pdf_text

# %%
# Print an example (first 100 characters of text for each file)
for filename, text in filename_text_dict.items():
    print(f"Filename: {filename}")
    print(f"Text Preview: {text[:100]}...\n")
print(len(filename_text_dict))
# Out:
# Filename: Musa acuminate 2021 Zahra.pdf
# Text Preview:
# 189 Zahra et al.
#
# Int. J. Biosci.
# 2021
#
#
# REVIEW PAPER                                      ...
#
# Filename: Musa acuminate 2023 Gervásio .pdf
# Text Preview: Review: Biological, antioxidant and phytochemical activities of Musa spp..
# Ciência Rural, v.53, n.12...
#
# Filename: Negalla staiva 2019 Nordin .pdf
# Text Preview: RESEARCH ARTICLE
# Open Access
# Effect of Nigella sativa and its bioactive
# compound on type 2 epithelia...
#
# Filename: Nigella sativa 2013 Ahmad .pdf
# Text Preview: 337
# Asian Pac J Trop Biomed 2013; 3(5): 337-352
# Asian Pacific Journal of Tropical Biomedicine
# journa...
#
# Filename: Nigella sativa 2017 Eid .pdf
# Text Preview: Review Article
# A Review on the Cosmeceutical and External
# Applications of Nigella sativa
# Ahmad M. Ei...
#
# Filename: Nigella sativa 2020  Begum.pdf
# Text Preview: Begum et al                                                                                         ...
#
# Filename: Nigella sativa 2020 Ahmad .pdf
# Text Preview: See discussions, stats, and author profiles for this publication at: https://www.researchgate.net/pu...
#
# Filename: Nigella sativa 2020 Sardoo .pdf
# Text Preview: See discussions, stats, and author profiles for this publication at: https://www.researchgate.net/pu...
#
# Filename: Nigella sativa 2021 Hannan .pdf
# Text Preview: nutrients
# Review
# Black Cumin (Nigella sativa L.): A Comprehensive Review on
# Phytochemistry, Health B...
#
# Filename: Nigella sativa 2021 Hossain .pdf
# Text Preview: Biomedicine & Pharmacotherapy 143 (2021) 112182
# Available online 1 October 2021
# 0753-3322/©
# 2021
# The...
#
# Filename: Nigella sativa 2023 Li.pdf
# Text Preview: TYPE Systematic Review
# PUBLISHED 28 March 2023
# DOI 10.3389/fnut.2023.1107750
# OPEN ACCESS
# EDITED BY
# M...
#
# Filename: Nigella sativa 2024 Alberts .pdf
# Text Preview: Citation: Alberts, A.; Moldoveanu,
# E.-T.; Niculescu, A.-G.; Grumezescu,
# A.M. Nigella sativa: A Compr...
#
# Filename: Nigella sative 2017 abdel-moneim .pdf
# Text Preview: RESEARCH ARTICLE
# Protective effect of Nigella sativa seeds against spermatocyte
# chromosomal aberrati...
#
# Filename: Ocimum bacilicum 2021 dhama .pdf
# Text Preview: Full Terms & Conditions of access and use can be found at
# https://www.tandfonline.com/action/journal...
#
# Filename: Ocimum basilicum  2023 Azizah .pdf
# Text Preview: Citation: Azizah, N.S.; Irawan, B.;
# Kusmoro, J.; Safriansyah, W.; Farabi,
# K.; Oktavia, D.; Doni, F.;...
#
# Filename: Ocimum basilicum 2012 Bariyah .pdf
# Text Preview: See discussions, stats, and author profiles for this publication at: https://www.researchgate.net/pu...
#
# Filename: Ocimum basilicum 2018 Balakrishnan .pdf
# Text Preview: See discussions, stats, and author profiles for this publication at: https://www.researchgate.net/pu...
#
# Filename: Ocimum basilicum 2022 Aminian .pdf
# Text Preview: The Effect of Ocimum basilicum L. and
# Its Main Ingredients on Respiratory
# Disorders: An Experimental...
#
# Filename: Ocimum basilicum 2022 Brandão .pdf
# Text Preview: Pharmacogn Rev. 2022;16(31):22-26
# A multifaceted peer reviewed journal in the field of Pharmacognosy...
#
# Filename: Ocimum basilicum 2022 Dharsono .pdf
# Text Preview: Citation: Dharsono, H.D.A.; Putri,
# S.A.; Kurnia, D.; Dudi, D.; Satari,
# M.H. Ocimum Species: A Review...
#
# Filename: Ocimum basilicum 2023  Kamelnia .pdf
# Text Preview:        *Corresponding author: Mohammad Hossein Boskabady. Applied Biomedical Research Center, Mashha...
#
# Filename: Ocimum basilicum 2023 Qamar.pdf
# Text Preview: Heliyon 9 (2023) e14644
# Available online 23 March 2023
# 2405-8440/© 2023 The Authors.
# Published by El...
#
# Filename: Ocimum basilicum 2024 Boulaares .pdf
# Text Preview: J Biochem Technol (2024) 15(1): 12-18
# https://doi.org/10.51847/TlkGjN14PM
# ISSN: 0974-2328
#
#
#
# ©...
#
# Filename: Ocimum basilicun  Fitriani Fitriyani .pdf
# Text Preview: Volume 5, Nomor 2, Oktober 2021
#
#
#
#
#
#
# ISSN2623-1581 (Online)
#
#                  ...
#
# Filename: Persea americana Ayodeji Precious Adesola 2024.pdf
# Text Preview: Nutritional, phytochemical and functional properties of avocado (Persea
# Americana Mill) leaf: Evalua...
#
# Filename: Persea americana Beata Olas 2024.pdf
# Text Preview: Citation: Olas, B. The Pulp, Peel, Seed,
# and Food Products of Persea americana
# as Sources of Bioacti...
#
# Filename: Persea americana Deepti Dabas 2014.pdf
# Text Preview: See discussions, stats, and author profiles for this publication at: https://www.researchgate.net/pu...
#
# Filename: Persea americana Mohammad Yasir 2010.pdf
# Text Preview: Pharmacognosy Reviews | January-June 2010 | Vol 4 | Issue 7
# 77
# The phytochemical and pharmacologica...
#
# Filename: Persea americana Tassew Belete Bahru 2019.pdf
# Text Preview: See discussions, stats, and author profiles for this publication at: https://www.researchgate.net/pu...
#
# Filename: Persea americana Uchechi Bliss Onyedikachi 2024.pdf
# Text Preview: Food Chemistry Advances 5 (2024) 100770
# Available online 6 July 2024
# 2772-753X/© 2024 The Author(s)....
#
# Filename: Persia Americana-Abdulrahman Mahmoud Dogara 2024.pdf
# Text Preview:
#
# Published by Tishk International University
# Available at: https://eajse.tiu.edu.iq/submit/
#
# ...
#
# Filename: Persia Americana-Alejandra Ochoa-Zarzosa 2020.pdf
# Text Preview: See discussions, stats, and author profiles for this publication at: https://www.researchgate.net/pu...
#
# Filename: Piper Nigrum Bahare Salehi 2019.pdf
# Text Preview: molecules
# Review
# Piper Species: A Comprehensive Review on Their
# Phytochemistry, Biological Activitie...
#
# Filename: Piper nigrum Fernando H. Sousa-2018.pdf
# Text Preview: 1
# Vol.:(0123456789)
# Scientific Reports |        (2020) 10:10703
# | https://doi.org/10.1038/s41598-0...
#
# Filename: Piper nigrum Heerasing Takooree 2019.pdf
# Text Preview: Full Terms & Conditions of access and use can be found at
# https://www.tandfonline.com/action/journal...
#
# Filename: Piper nigrum Rama Shukla.pdf
# Text Preview: See discussions, stats, and author profiles for this publication at: https://www.researchgate.net/pu...
#
# Filename: Piper nigrum Zoheir A Damanhouri 2014.pdf
# Text Preview: See discussions, stats, and author profiles for this publication at: https://www.researchgate.net/pu...
#
# Filename: Piperine  nigrum Iahtisham-Ul Haq 2020.pdf
# Text Preview: R E V I E W
# Piperine: A review of its biological effects
# Iahtisham-Ul Haq1
# |
# Muhammad Imran2
# |
# Muham...
#
# Filename: Salvia hispanica L  Mariana Grancieri 2019.pdf
# Text Preview: Chia Seed (Salvia hispanica L.) as a Source of
# Proteins and Bioactive Peptides with Health
# Beneﬁts: ...
#
# Filename: Salvia hispanica L. Cynthia de Souza Ferreira 2015.pdf
# Text Preview:
# Nutrición Hospitalaria
# ISSN: 0212-1611
# info@nutriciónhospitalaria.com
# Grupo Aula Médica
# España
# d...
#
# Filename: Salvia hispanica L. Rahman Ullah 2015.pdf
# Text Preview: REVIEW
# Nutritional and therapeutic perspectives of Chia (Salvia hispanica
# L.): a review
# Rahman Ullah...
#
# Filename: Salvia hispanica-Mehdi Karimi-2024.pdf
# Text Preview: Karimi et al. Nutrition & Metabolism           (2024) 21:74
# https://doi.org/10.1186/s12986-024-008...
#
# Filename: Salvia hispanica-Sara Motyka-17 March 2023.pdf
# Text Preview: Citation: Motyka, S.; Kusznierewicz,
# B.; Ekiert, H.; Korona-Głowniak, I.;
# Szopa, A. Comparative Anal...
#
# Filename: Salvia HispanicaL Carla Georgina Cicero-Sarmientoa 2023.pdf
# Text Preview: See discussions, stats, and author profiles for this publication at: https://www.researchgate.net/pu...
#
# Filename: Taraxacum Officinale Agnese 2021.pdf
# Text Preview: Di Napoli and Zucchetti ﻿Bull Natl Res Cent          (2021) 45:110
# https://doi.org/10.1186/s42269-...
#
# Filename: Taraxacum officinale Brooke 2005.pdf
# Text Preview: Journal Of Herbal Pharmacotherapy
# ISSN: 1522-8940 (Print) 1522-9106 (Online) Journal homepage: www.t...
#
# Filename: Taraxacum officinale Busra 2024.pdf
# Text Preview: Journal of Culinary Science & Technology
# ISSN: (Print) (Online) Journal homepage: www.tandfonline.co...
#
# Filename: Taraxacum Officinale Fonyuy 2015.pdf
# Text Preview: REVIEW
#
#
#
#
#
#
# www.The-RDS.org
# 113
#
# DOI 10.1900/RDS.2016.13.113
# DIABETIC
# STUDIES
# The Rev...
#
# Filename: Taraxacum officinale Jalili 2010 .pdf
# Text Preview: 1
# AN OVERVIEW OF THERAPEUTIC
# POTENTIALS OF TARAXACUM OFFICINALE
# (DANDELION): A TRADITIONALLY VALUA...
#
# Filename: Taraxacum Officinale Katrin 2006.pdf
# Text Preview: Journal of Ethnopharmacology 107 (2006) 313–323
# Review
# Taraxacum—A review on its phytochemical and p...
#
# Filename: Taraxacum officinale Marta 2012.pdf
# Text Preview: Diverse biological activities of dandelion
# Marta González-Castejón, Francesco Visioli, and Arantxa R...
#
# Filename: Taraxacum officinale Min 2023.pdf
# Text Preview: Citation: Fan, M.; Zhang, X.;
# Song, H.; Zhang, Y. Dandelion
# (Taraxacum Genus): A Review of
# Chemical ...
#
# Filename: Taraxacum officinale Qingzi 2024.pdf
# Text Preview: Review
# The phytochemical and pharmacological profile of dandelion
# Qingzi Yan a, Qichang Xing a, Zhen...
#
# Filename: Taraxacum Officinale Raziye 2024.pdf
# Text Preview: GUHES 2024; 6 (3): 152-158                                                                          ...
#
# Filename: Taraxacum officinale Sheezan 2014 .pdf
# Text Preview: Annals of Plant Sciences
# ISSN: 2287-688X
# OPEN ACCESS
# www.annalsofplantsciences.com
#       Review ...
#
# Filename: Trigonella foenum graecum L Jasim 2014.pdf
# Text Preview: See discussions, stats, and author profiles for this publication at: https://www.researchgate.net/pu...
#
# Filename: Trigonella foenum graecum L Taloubi 2013.pdf
# Text Preview: Taloubi et al., IJPSR, 2013; Vol. 4(2): 516-519
#
#
#
#
#
#           ...
#
# Filename: Trigonella foenum-graecum L Adeolu 2014.pdf
# Text Preview: AMERICAN
# JOURNAL
# OF SOCIAL ISSUES AND HUMANITIES
# OPEN   ACCESS
# AJSIH | ISSN: 2276 – 6928        ...
#
# Filename: Trigonella foenum-graecum L Theysshana 2022.pdf
# Text Preview:
#
# Citation: Visuvanathan, T.; Than,
# L.T.L.; Stanslas, J.; Chew, S.Y.;
# Vellasamy, S. ...
#
# Filename: Trigonella foenum-graecum L Umesh 2014.pdf
# Text Preview: Pharmaceutical Biology
# ISSN: 1388-0209 (Print) 1744-5116 (Online) Journal homepage: www.tandfonline....
#
# Filename: Trigonella foenum-graecum Nathiya 2014.pdf
# Text Preview: See discussions, stats, and author profiles for this publication at: https://www.researchgate.net/pu...
#
# Filename: Trigonella foenum-graecum Pushpa 2022.pdf
# Text Preview: Review
# Fenugreek (Trigonella foenum-graecum): Nutraceutical values,
# phytochemical, ethnomedicinal an...
#
# Filename: Trigonella foenum-graecum Savita 2008.pdf
# Text Preview: Acta Poloniae Pharmaceutica ñ Drug Research, Vol. 65 No. 4 pp. 473ñ476, 2008
# ISSN 0001-6837
# Polish P...
#
# Filename: Trigonella foenum-graecum Srinivasan 2006.pdf
# Text Preview: Food Reviews International
# ISSN: 8755-9129 (Print) 1525-6103 (Online) Journal homepage: www.tandfonl...
#
# Filename: Trigonellafoenum-graecum L Ahmadiani 1999.pdf
# Text Preview: Journal of Ethnopharmacology 75 (2001) 283–286
# Short Communication
# Anti-inﬂammatory and antipyretic ...
#
# Filename: Trigonellafoenum-graecum L Kalyan 2016.pdf
# Text Preview: 1600950 (1 of 26)
# Mol. Nutr. Food Res. 61, 6, 2017, 1600950
# DOI 10.1002/mnfr.201600950
# REVIEW
# A smal...
#
# 66

# %%
import os
from openai import OpenAI
import json
import time
data = []
for filename, text in filename_text_dict.items():
    user_prompt = """Here is the research paper. Extract the relevant information as per the structure provided, the output should ben in a json format as text. 
    Research paper:"""+ text
    try:
        client = OpenAI(
            # If the environment variable is not configured, replace the following line with: api_key="sk-xxx",
            api_key=QWEN_API_KEY,
            base_url="https://dashscope-intl.aliyuncs.com/compatible-mode/v1",
        )

        completion = client.chat.completions.create(
            model="qwen-plus",
            messages=[
                {'role': 'system', 'content': system_prompt},
                {'role': 'user', 'content': user_prompt}
                ]
        )
        print(completion.choices[0].message.content)
        raw_output = completion.choices[0].message.content
        json_start = raw_output.find('{')
        json_end = raw_output.rfind('}') + 1
        json_str = raw_output[json_start:json_end]
        json_output = json.loads(json_str)
        # Append to the data list with filename as a key
        data.append({"filename": filename, **json_output})
        print(len(data))
    except Exception as e:
        print(f"Error message: {e}")
        print("For more information, see: https://www.alibabacloud.com/help/en/model-studio/developer-reference/error-code")
    time.sleep(2)  # Sleep for 1 second to avoid rate limiting
# Convert to DataFrame
df = pd.DataFrame(data)
# Export DataFrame to an Excel file
df.to_excel("herbal_medicine_output.xlsx", index=False)
# Out:
# ```json
# {
#   "Title": "Health Benefits of Banana (Musa) - A Review Study",
#   "Authors": "Fatima Zahra, Sidra Khalid, Maria Aslam, Zainab Sharmeen",
#   "Year": "2021",
#   "Scientific name of Medicinal plant": "Musa spp., Musa paradisiaca, Musa acuminata",
#   "Medicinal use": "Banana is used to treat and prevent diseases such as cancer, ulcer, Alzheimer’s disease, infection, diarrhea, hemorrhoids, diabetes, and hypertension due to its antifungal, antibiotic, antimicrobial, antidiabetic, antioxidant, and anti-inflammatory properties.",
#   "Biological activity": "The biological activities include antimicrobial, antifungal, antidiabetic, antioxidant, anti-inflammatory, and immunomodulatory properties. It also has the ability to reduce oxidative stress, maintain electrolyte balance, and act as a prebiotic.",
#   "Dose": "Not mentioned",
#   "Phytochemicals": "Phenols, flavonoids, triterpenes, oxalic acid, starch, tannin, glycosides, sulphate, dopamine, norepinephrine, serotonin, campesterol, stigmasterol, catechin, ferulic acid, p-coumaric acid, cryptoxanthin, quercetin",
#   "Plant part used": "Pulp, peel, leaves, flower, seeds, sap, pseudo stem, rhizome",
#   "Formulation": "Not mentioned",
#   "Botanic description": "Not mentioned",
#   "Toxicity": "Not mentioned",
#   "Adverse reactions": "Not mentioned",
#   "Health Benefits": "Banana provides immediate energy, improves intestinal health, reduces the risk of cancer, protects from cardiovascular diseases, helps in weight management, lowers blood pressure, maintains kidney health, prevents ulcers, aids in depression, and alleviates menstrual pain. It also acts as an anti-wrinkle treatment and face mask for skin care.",
#   "Nutritional benefits": "Rich in potassium, vitamins A, B6, C, D, dietary fiber, micro-nutrients like vitamin B6, vitamin C, biotin, minerals like manganese, copper, and antioxidants. It has low glycemic index and low calories, making it suitable for diabetic patients.",
#   "Reference": "Zahra, F., Khalid, S., Aslam, M., & Sharmeen, Z. (2021). Health benefits of banana (Musa)- A review study. International Journal of Biosciences, 18(4), 189-199. http://dx.doi.org/10.12692/ijb/18.4.189-199"
# }
# ```
# 1
# ```json
# {
#   "Title": "Review: Biological, Antioxidant And Phytochemical Activities Of Musa Spp.",
#   "Authors": "Suiany Vitorino Gervásio, Maria do Carmo Pimentel Batitucci",
#   "Year": 2023,
#   "Scientific name of Medicinal plant": "Musa acuminata, Musa balbisiana, Musa paradisiaca",
#   "Medicinal use": "Banana is used for its antibacterial, anticancer, antifungal, and antitoxic properties. It also has chemopreventive and antihyperglycemic potential.",
#   "Biological activity": "The biological activities include antibacterial, anticancer, antifungal, antitoxic, antituberculosis, mycobactericidal, chemopreventive, and antihyperglycemic effects. These activities are attributed to the presence of phytochemicals such as flavonoids, phenols, tannins, and alkaloids.",
#   "Dose": "Not mentioned",
#   "Phytochemicals": "Flavonoids, phenols, tannins, alkaloids, steroids, polyphenols, saponins, glycosides, cardiac glycosides, anthraquinone, terpenoids, cinnamic acids, proteins, reducing sugars, phytosterols, quinones, coumarins, fatty acids, phenolic acids, catecholamines, long-chain aliphatic compounds",
#   "Plant part used": "Fruit (pulp and peel), leaves, bracts, inflorescences, pseudostem exudates, stem juice",
#   "Formulation": "Extracts prepared using solvents like ethanol, methanol, water, hexane, acetone, ethyl acetate, DMSO, and 70% ethanol. Maceration was the most common extraction method. Some studies used liquid nitrogen spraying for fruit pulp.",
#   "Botanic description": "Not mentioned",
#   "Toxicity": "Toxicity was reported for the leaves of Musa spp., but specific details were not provided.",
#   "Adverse reactions": "Not mentioned",
#   "Health Benefits": "Rich in flavonoids, bananas exhibit good performance in DPPH and FRAP antioxidant assays and have antibacterial, anticancer, and antifungal potential.",
#   "Nutritional benefits": "Banana is a staple and affordable food that causes satiety, is rich in nutrients, and is easy to reproduce and manipulate.",
#   "Reference": "Gervásio, S. V., & Batitucci, M. do C. P. (2023). Review: Biological, antioxidant and phytochemical activities of Musa spp. Ciência Rural, 53(12), e20220636. https://doi.org/10.1590/0103-8478cr20220636"
# }
# ```
# 2
# ```json
# {
#   "Title": "Effect Of Nigella Sativa And Its Bioactive Compound On Type 2 Epithelial To Mesenchymal Transition: A Systematic Review",
#   "Authors": "Abid Nordin, Haziq Kamal, Muhammad Dain Yazid, Aminuddin Saim, Ruszymah Idrus",
#   "Year": "2019",
#   "Scientific name of Medicinal plant": "Nigella sativa",
#   "Medicinal use": "Used for wound healing, attenuation of inflammation, and prevention of organ fibrosis.",
#   "Biological activity": "Anti-inflammatory, anti-oxidant, anti-bacterial, anti-diabetic, anti-angiogenic, and organ-protective properties. It promotes wound healing via regulation of the epithelial-to-mesenchymal transition (EMT) process.",
#   "Dose": "Dosages varied depending on the study and formulation: topical applications (e.g., creams, oils), oral doses ranging from 5 mg/kg/day to 50 mg/kg/day for thymoquinone, and 1 ml/kg to 2.5 ml/kg for Nigella sativa oil.",
#   "Phytochemicals": "Thymoquinone, dithymoquinone, dihydrothymoquinone",
#   "Plant part used": "Seeds (oil extracted from seeds)",
#   "Formulation": "Oil ointment, cream, honey, propolis, microemulsion, nanofiber delivery systems",
#   "Botanic description": "Not mentioned",
#   "Toxicity": "Not mentioned",
#   "Adverse reactions": "Not mentioned",
#   "Health Benefits": "Enhances wound healing, reduces inflammation, prevents organ fibrosis, protects against cardiac damage, alleviates lung fibrosis, mitigates nephropathy, and ameliorates liver injury.",
#   "Nutritional benefits": "Not mentioned",
#   "Reference": "Nordin, A., Kamal, H., Yazid, M. D., Saim, A., & Idrus, R. (2019). Effect of Nigella sativa and its bioactive compound on type 2 epithelial to mesenchymal transition: a systematic review. BMC Complementary and Alternative Medicine, 19, 290. https://doi.org/10.1186/s12906-019-2706-2"
# }
# ```
# 3
# ```json
# {
#   "Title": "A Review on Therapeutic Potential of Nigella Sativa: A Miracle Herb",
#   "Authors": "Aftab Ahmad, Asif Husain, Mohd Mujeeb, Shah Alam Khan, Abul Kalam Najmi, Nasir Ali Siddique, Zoheir A. Damanhouri, Firoz Anwar",
#   "Year": 2013,
#   "Scientific name of Medicinal plant": "Nigella sativa",
#   "Medicinal use": "Used in the treatment and prevention of a variety of diseases including respiratory issues, diabetes, cancer, gastrointestinal disorders, liver and kidney protection, cardiovascular conditions, neurological disorders, skin ailments, and as an anti-inflammatory, antioxidant, and immunomodulatory agent.",
#   "Biological activity": "The biological activities include antibacterial, antifungal, antischistosomal, antioxidant, antidiabetic, anticancer, anti-inflammatory, analgesic, immunomodulatory, cardiovascular, gastroprotective, hepatoprotective, nephroprotective, pulmonary-protective, anticonvulsant, contraceptive, antioxytocic, and neuropharmacological effects.",
#   "Dose": "Dosages vary depending on the condition treated; examples include 2 g/day for type 2 diabetes mellitus, thymoquinone administered at 5 mg/kg body weight for arthritis, and intraperitoneal doses of TQ (10-20 mg/kg) for anxiety studies. Specific dosages are provided for certain formulations but not universally applicable.",
#   "Phytochemicals": "Thymoquinone, thymohydroquinone, dithymoquinone, p-cymene, carvacrol, nigellidine, nigellicine, alpha-hederin, saponins, nigellone, flavonoids, alkaloids, fixed oils, unsaturated fatty acids, sterols, terpenes, and various antioxidants.",
#   "Plant part used": "Seeds, seed oil, and occasionally roots or shoots.",
#   "Formulation": "Available as seeds, seed oil, aqueous suspension, capsules, extracts, volatile oil, boiled extract, hexane extract, ethanol extract, methanol extract, among others.",
#   "Botanic description": "An annual flowering plant growing up to 20-90 cm tall with finely divided leaves, white, yellow, pink, pale blue or purple flowers, and a large inflated capsule containing numerous seeds that are small, trigonus, angular, regulose-tubercular, and black externally with a white interior.",
#   "Toxicity": "Low toxicity reported; LD50 values indicate safety when administered orally. Chronic administration did not cause significant changes in hepatic enzyme levels or histopathology. However, potential interactions with drugs metabolized by cytochrome P450 enzymes exist.",
#   "Adverse reactions": "Not mentioned.",
#   "Health Benefits": "Promotes general well-being, supports immune system function, improves metabolic health, protects against oxidative stress, enhances respiratory health, aids digestion, and may support bone health and fertility regulation.",
#   "Nutritional benefits": "Rich in vitamins (e.g., vitamin A), minerals (Cu, P, Zn, Fe), proteins, fats, carbohydrates, fiber, and essential oils contributing to its nutritional value.",
#   "Reference": "Ahmad, A., Husain, A., Mujeeb, M., Khan, S. A., Najmi, A. K., Siddique, N. A., Damanhouri, Z. A., & Anwar, F. (2013). A review on therapeutic potential of Nigella sativa: A miracle herb. Asian Pacific Journal of Tropical Biomedicine, 3(5), 337-352. https://doi.org/10.1016/S2221-1691(13)60075-1"
# }
# ```
# 4
# ```json
# {
#   "Title": "A Review on the Cosmeceutical and External Applications of Nigella sativa",
#   "Authors": "Ahmad M. Eid, Nagib A. Elmarzugi, Laila M. Abu Ayyash, Maher N. Sawafta, Hadeel I. Daana",
#   "Year": 2017,
#   "Scientific name of Medicinal plant": "Nigella sativa",
#   "Medicinal use": "Used for acne vulgaris, skin cancer, pigmentation, wound healing, anti-inflammatory effects, cosmeceutical applications, treatment of vitiligo, antipsoriatic effects, and as an antimicrobial, antiviral, antifungal, and antiparasitic agent.",
#   "Biological activity": "Antimicrobial (antibacterial, antiviral, antifungal), anti-inflammatory, antioxidant, wound healing, antipsoriatic, antiparasitic, hepatoprotective, and immunomodulatory activities.",
#   "Dose": "Not mentioned",
#   "Phytochemicals": "Thymoquinone, thymohydroquinone, dithymoquinone, thymol, nigellicine, carvacrol, nigellimine, nigellidine, alpha-hederin",
#   "Plant part used": "Seeds",
#   "Formulation": "Oil, capsules, ointment, lotion, gel, cream, shampoo, soap",
#   "Botanic description": "Small shrub with tapering green leaves and rosaceous white and purplish flowers. The fruit contains tiny dark black seeds.",
#   "Toxicity": "Very low degree of toxicity. Only two cases of contact dermatitis reported after topical use. No significant toxicological or adverse effects on liver or kidney functions.",
#   "Adverse reactions": "Contact dermatitis in two patients; otherwise, no significant adverse effects noted.",
#   "Health Benefits": "Treatment of various diseases such as asthma, hypertension, paralysis, amenorrhea, anorexia, rheumatism, diabetes, gastrointestinal diseases, skin diseases, allergies, and parasitic infections.",
#   "Nutritional benefits": "Not mentioned",
#   "Reference": "Eid, A. M., Elmarzugi, N. A., Abu Ayyash, L. M., Sawafta, M. N., & Daana, H. I. (2017). A review on the cosmeceutical and external applications of Nigella sativa. Journal of Tropical Medicine, 2017, Article ID 7092514. https://doi.org/10.1155/2017/7092514"
# }
# ```
# 5
# ```json
# {
#   "Title": "A Review On Nigella Sativa: A Marvel Herb",
#   "Authors": "Safiya Begum, Dr. Abdul Mannan",
#   "Year": 2020,
#   "Scientific name of Medicinal plant": "Nigella sativa",
#   "Medicinal use": "The seeds and oil of Nigella sativa have been widely used in the treatment of various diseases such as bronchitis, asthma, diarrhea, rheumatism, skin disorders, diabetes, hypertension, intrinsic hemorrhage, paralysis, amenorrhea, anorexia, cough, bronchitis, headache, fever, influenza, and eczema.",
#   "Biological activity": "Nigella sativa exhibits a wide range of biological activities including antioxidant, anti-inflammatory, antibacterial, antifungal, antiparasitic, antiprotozoal, antiviral, cytotoxic, anticancer, neuroprotective, gastroprotective, cardioprotective, hepatoprotective, nephroprotective, immunomodulatory, diuretic, antihypertensive, antidiabetic, analgesic, anthelmintic, spasmolytic, bronchodilator, and wound healing properties.",
#   "Dose": "Not mentioned",
#   "Phytochemicals": "Thymoquinone, thymohydroquinone, dithymoquinone, p-cymene, carvacrol, 4-terpineol, t-anethol, longifolene, α-pinene, thymol, nigellicimine, nigellicimine N - oxide, nigellidine, nigellicine, alpha-hederin, saponin, vanillic acid, carvone, limonene, citronellol.",
#   "Plant part used": "Seeds",
#   "Formulation": "Oil, boiled extract, capsules, lotion, cream.",
#   "Botanic description": "Nigella sativa is an annual flowering plant that grows to a height of 20–30 cm with linear lanceolate leaves. The flowers are delicate with 5-10 petals and come in colors like yellow, white, pink, pale blue, or pale violet. The fruit is a large inflated capsule consisting of 3-7 united follicles with numerous seeds each. The seeds are black, flattened, oblong, and angular with a funnel shape.",
#   "Toxicity": "Not mentioned",
#   "Adverse reactions": "Not mentioned",
#   "Health Benefits": "Nigella sativa provides health benefits such as improving immunity, reducing oxidative stress, enhancing wound healing, protecting against cardiovascular, hepatic, renal, and pulmonary damage, managing diabetes, and combating aging effects.",
#   "Nutritional benefits": "Nigella sativa seeds contain protein (26.7%), fat (28.5%), carbohydrates (24.9%), crude fiber (8.4%), total ash (4.8%), vitamins, and minerals such as Cu, P, Zn, Fe.",
#   "Reference": "Begum, S., & Mannan, A. (2020). A Review on Nigella sativa: A Marvel Herb. Journal of Drug Delivery & Therapeutics, 10(2), 213-219. http://dx.doi.org/10.22270/jddt.v10i2.3913"
# }
# ```
# 6
# ```json
# {
#   "Title": "An updated knowledge of Black seed (Nigella sativa Linn.): Review of phytochemical constituents and pharmacological properties",
#   "Authors": "Md Faruque Ahmad, Fakhruddin Ali Ahmad, Syed Amir Ashraf, Hisham H. Saad, Shadma Wahab, Mohammed Idreesh Khan, M. Ali, Syam Mohan, Khalid Rehman Hakeem, Md Tanwir Athar",
#   "Year": "2021",
#   "Scientific name of Medicinal plant": "Nigella sativa",
#   "Medicinal use": "Used for asthma, fever, bronchitis, cough, chest congestion, dizziness, paralysis, chronic headache, back pain, inflammation, infertility, gastrointestinal disorders, abscess, nasal ulcer, swollen joint, orchitis, eczema.",
#   "Biological activity": "Antidiabetic, antitussive, anticancer, antioxidant, hepatoprotective, neuroprotective, gastroprotective, immunomodulator, analgesic, antimicrobial, anti-inflammatory, spasmolytic, bronchodilator, cardioprotective, antihypertensive, antiatherogenic, improve endothelial function, anticancer, anti-diabetic, neuroprotective, anti-dyslipidemic, anti-obesity, immunomodulatory, antihistaminic, anthelmintic, anti-infertility, anti-nociceptive & anti-inflammatory, oral ulcerations and mucositis healing, nephroprotective, antiarthritic.",
#   "Dose": "Not mentioned.",
#   "Phytochemicals": "Thymoquinone, p-cymene, α-pinene, thymohydroquinone, dihydrothymoquinone, carvacrol, t-anethole, β-pinene, γ-terpinene, nigellone, oleic acid, linoleic acid, palmitic acid, stearic acid, quercetin, kaempferol 3-glucosyl galactoside, vanillic acid, hydroxybenzoic acid, syringic acid, p-cumaric acids, valine, phenylalanine, threonine, methionine, histidine, tryptophan, leucine, isoleucine, lysine, calcium, iron, potassium, phosphorus, zinc.",
#   "Plant part used": "Seeds",
#   "Formulation": "Oil, powder, extract, capsules.",
#   "Botanic description": "Green plant with finely divided linear leaves, pale blue and white flowers with 5-10 petals, inflated capsule fruits divided into 3-7 united follicles, each containing numerous black seeds oval in shape and measuring about 1 mm in diameter.",
#   "Toxicity": "Not mentioned.",
#   "Adverse reactions": "Not mentioned.",
#   "Health Benefits": "Antioxidant, anti-inflammatory, antimicrobial, cardio protective, gastroprotective, neuroprotective, anti-diabetic, anticancer, anti-dyslipidemic, anti-obesity, immunomodulatory, antihistaminic, anthelmintic, anti-infertility, anti-nociceptive & anti-inflammatory, oral ulcerations and mucositis healing, nephroprotective, antiarthritic.",
#   "Nutritional benefits": "Rich in unsaturated fatty acids, alkaloids, coumarins, saponins, flavonoids, fixed oils, phenolics, myristic acid, vitamins, and trace metals which add value to its medicinal properties.",
#   "Reference": "Ahmad, M.F., Ahmad, F.A., Ashraf, S.A., et al. (2021). An updated knowledge of Black seed (Nigella sativa Linn.): Review of phytochemical constituents and pharmacological properties. Journal of Herbal Medicine, 25, 100404. https://doi.org/10.1016/j.hermed.2020.100404"
# }
# ```
# 7
# ```json
# {
#   "Title": "Nigella sativa (black seed) safety: an overview",
#   "Authors": "Habibeh Mashayekhi-Sardoo, Ramin Rezaee, Gholamreza Karimi",
#   "Year": 2020,
#   "Scientific name of Medicinal plant": "Nigella sativa",
#   "Medicinal use": "Traditionally used for treating disorders such as bronchitis, asthma, inflammatory, infectious, and gastrointestinal diseases. Also applied for skin diseases like boils and eczema. Used in the treatment of fever, chronic headache, migraine, hypertension, paralysis, as a laxative, intestinal antiprotozoal agent, and carminative.",
#   "Biological activity": "Reported pharmacological activities include antibacterial, anticancer, anti-inflammatory, antioxidant, immunomodulatory, analgesic, diuretic, antihypertensive, antidiabetic, neuroprotective, gastroprotective, and hepatoprotective properties.",
#   "Dose": "LD50 values vary from 28.8 mL/kg to 3,371 mg/kg in mice for different extracts. Subacute doses up to 6 g/kg/day were found safe in some studies. Chronic toxicity studies indicate slight toxicity at 2 mL/kg in rats. Human trials show safety at doses up to 5 mL/day for 26 days.",
#   "Phytochemicals": "Thymoquinone, carvacrol, 4-cymene, pentacyclic triterpenoid saponins (alpha-hederin), alkaloids (nigellicine, nigellicimine, nigellicimine-N-oxide, nigellidine), fixed oil, carbohydrates, proteins, fiber, minerals, volatile oil, essential oil.",
#   "Plant part used": "Seeds",
#   "Formulation": "Oil, aqueous extract, methanol extract, chloroform extract, powder, capsules, ethanolic extract, petroleum ether extract, aqueous extract.",
#   "Botanic description": "Not mentioned",
#   "Toxicity": "Acute toxicity varies depending on the extract type. Fixed oil is less toxic compared to volatile oil. Subacute and chronic toxicity evaluations indicate slight toxicity at higher doses. Cytotoxic effects observed in certain cell lines but generally regarded as safe.",
#   "Adverse reactions": "Allergic contact dermatitis, bloating, nausea, burning sensation, slight increase in kidney and liver enzymes, epigastric pain, hypoglycemia, severe bullous target-like lesions compatible with erythema multiforme.",
#   "Health Benefits": "Used for neurological disorders, hypertension, hyperlipidemia, obesity, rheumatoid arthritis, lung disease, thyroid dysfunction, hepatitis, male infertility.",
#   "Nutritional benefits": "Not mentioned",
#   "Reference": "Mashayekhi-Sardoo, H., Rezaee, R., & Karimi, G. (2020). Nigella sativa (black seed) safety: an overview. Asian Biomedicine, 14(4), 127–137. https://doi.org/10.1515/abm-2020-0020"
# }
# ```
# 8
# ```json
# {
#   "Title": "Black Cumin (Nigella sativa L.): A Comprehensive Review on Phytochemistry, Health Benefits, Molecular Pharmacology, and Safety",
#   "Authors": "Md. Abdul Hannan, Md. Ataur Rahman, Abdullah Al Mamun Sohag, Md. Jamal Uddin, Raju Dash, Mahmudul Hasan Sikder, Md. Saidur Rahman, Binod Timalsina, Yeasmin Akter Munni, Partha Protim Sarker, Mahboob Alam, Md. Mohibbullah, Md. Nazmul Haque, Israt Jahan, Md. Tahmeed Hossain, Tania Afrin, Md. Mahbubur Rahman, Md. Tahjib-Ul-Arif, Sarmistha Mitra, Diyah Fatimah Oktaviani, Md Kawsar Khan, Ho Jin Choi, Il Soo Moon, Bonglee Kim",
#   "Year": "2021",
#   "Scientific name of Medicinal plant": "Nigella sativa L.",
#   "Medicinal use": "The paper describes the medicinal use of Nigella sativa L., also known as black cumin or black seeds, for a wide range of conditions including asthma, bronchitis, rheumatism, headache, back pain, anorexia, amenorrhea, paralysis, inflammation, mental debility, eczema, hypertension, cancer, neurological disorders, diabetes, cardiovascular diseases, gastrointestinal issues, reproductive health, skin diseases, arthritis, nephroprotective effects, anti-obesity, bone regenerative effects, hepatoprotective effects, pulmonary protective effects, and more.",
#   "Biological activity": "Nigella sativa L. exhibits antioxidant, anti-inflammatory, immunomodulatory, anticancer, neuroprotective, antimicrobial, antihypertensive, cardioprotective, antidiabetic, gastroprotective, nephroprotective, and hepatoprotective activities. The main bioactive compound, thymoquinone (TQ), contributes significantly to these pharmacological effects by modulating multiple cellular signaling systems such as Nrf2, NF-κB, TLR, SIRT1, AMPK-SIRT1-PGC-1α, PPAR, and PI3K/Akt signaling pathways.",
#   "Dose": "Dosages vary depending on the condition being treated. Examples include: 600 mg/kg of black cumin seeds in rabbits, 2 g/day in patients with Hashimoto’s thyroiditis, 2 mL/kg in STZ-induced diabetic rats, and 5 mg/kg/day for seven days in Feeney’s falling weight-induced moderate head trauma in rats. Intraperitoneal doses range from 5–50 mg/kg, while oral doses can be up to 2 g/day in humans.",
#   "Phytochemicals": "Thymoquinone (TQ), thymohydroquinone, thymol, carvacrol, nigellicimine, nigellicimine-N-oxide, nigellidine, nigellicine, γ-tocopherol, β-sitosterol, stigmasterol, caftaric acid, gentisic acid, caffeic acid, chlorogenic acid, p-coumaric acid, ferulic acid, sinapic acid, cichoric acid, hyperoside, isoquercitrin, rutin, myricetin, fisetin, quercitrin, quercetin, patuletin, luteolin, kaempferol, apigenin, α-pinene, p-cymene, sesquiterpene longifolene, and several others.",
#   "Plant part used": "Seeds are primarily used for medicinal purposes. Extracts are derived from the seeds, and essential oil is obtained through hydrodistillation.",
#   "Formulation": "The formulations include seed powder, essential oil (NSO), nanoemulsions, hydroethanolic extracts, capsules, ethosomes gel, and topical creams. Some studies also mention combinations with honey or other natural products.",
#   "Botanic description": "Not mentioned",
#   "Toxicity": "Toxicity depends on dose size, route of administration, duration of exposure, and animal model. Studies indicate that intraperitoneally administered TQ has lower non-toxic and toxic doses compared to oral administration. LD50 values vary between species and routes of administration, with oral TQ generally safer than intraperitoneal TQ.",
#   "Adverse reactions": "Some adverse effects reported include nausea, bloating, and burning sensation in functional dyspeptic patients. There was also a slight increase in liver and kidney enzymatic markers following NSO and crushed seed consumption. High doses may cause chromosomal aberrations and DNA damage in liver and kidney tissues.",
#   "Health Benefits": "Nigella sativa L. provides numerous health benefits, including protection against oxidative stress, inflammation, neurodegenerative diseases, cancer, metabolic syndromes, liver and kidney damage, skin diseases, respiratory issues, fertility enhancement, and wound healing. It also acts as an antidote against various toxins.",
#   "Nutritional benefits": "Black cumin contains protein, fat, essential fatty acids, amino acids, vitamins (A, E, C, folic acid, thiamin, riboflavin, pyridoxine, niacin), minerals, and phytosterols, contributing to its nutritional value.",
#   "Reference": "Hannan, M.A.; Rahman, M.A.; Sohag, A.A.M.; Uddin, M.J.; Dash, R.; Sikder, M.H.; Rahman, M.S.; Timalsina, B.; Munni, Y.A.; Sarker, P.P.; et al. Black Cumin (Nigella sativa L.): A Comprehensive Review on Phytochemistry, Health Benefits, Molecular Pharmacology, and Safety. Nutrients 2021, 13, 1784. https://doi.org/10.3390/nu13061784."
# }
# ```
# 9
# ```json
# {
#   "Title": "A Review of Ethnobotany, Phytochemistry, Antimicrobial Pharmacology and Toxicology of Nigella sativa L.",
#   "Authors": "Md. Sanower Hossain, Ashik Sharfaraz, Amit Dutta, Asif Ahsan, Md. Anwarul Masud, Idris Adewale Ahmed, Bey Hing Goh, Zannat Urbi, Md. Moklesur Rahman Sarker, Long Chiau Ming",
#   "Year": "2021",
#   "Scientific name of Medicinal plant": "Nigella sativa L.",
#   "Medicinal use": "The seeds or extracted oil of Nigella sativa are traditionally used alone or in combination with other products like honey, lint, melted butter, and astringents in Islamic medicine, ayurvedic medicine, Unani traditional medicine, and indigenous medicine. They are used for various diseases or health conditions, including abdominal disorders, abscesses, anorexia, worm infections, asthma, bronchitis, cardiovascular disease, chronic headache, colic, coryza, coughs, dermatosis, diabetes, diarrhea, dispiritedness, eye infections, fatigue, fever, galactopoiesis, headaches, hemorrhoids, hypertension, jaundice, liver ailments, metabolic syndrome, nasal ulcers, obesity, orchitis, pulmonosis, reproductive disorders, respiratory infections, rheumatism, sinusitis and sore eyes, and also as a stimulant for body energy.",
#   "Biological activity": "Nigella sativa displays diverse pharmacological actions, including antimicrobial activities. The active compounds such as thymoquinone can induce oxidative stress, cell apoptosis (by producing reactive oxygen species), increase membrane permeability, inhibit efflux pumps, and impose strong biocidal actions. It has antibacterial, antiviral, antifungal, and anti-parasitic properties. Additionally, it shows anti-inflammatory, anticancer, antioxidant, and immunomodulatory effects.",
#   "Dose": "Various doses have been reported: Grounded NS supplement of 2 gm/day for three months improved glycemia in type-2 diabetes mellitus patients; 500 mg capsules taken for nine weeks increased executive functions in the elderly; 500 mg capsules daily for four weeks reduced anxiety and improved memory. For treating COVID-19, one large spoonful of Nigella sativa oil (or 2 g of Nigella sativa seeds) mixed with one gram of ground anthemis hyaline and one large spoonful of natural honey was recommended.",
#   "Phytochemicals": "Thymoquinone, p-cymene, α-thujene, carvacrol, β-pinene, limonole, methyl linoleate, sabinene, D-limonene, 4,5-epoxy-1-isopropyl-4-methyl-1-cyclohexene, 4-terpineol, nigellidine, nigellimine, nigellamine A1-A5, B1-B2, C, oleic acid, palmitic acid, stearic acid, eicosadienoic acid, linolenic acid, ferulic acid, sinapinic acid, quercetin, kaempferol, β-sitosterol, stigmasterol, δ-7-stigmasterol, δ-7-avenasterol, campesterol, cholesterol, longifolene, α-hederin, eugenol, ε-cinnamaldehyde, n-nonane, dodecanal, tetradecanal, myrtenol, citronellyl n-butyrate, benzaldehyde, coumarin, DL-Arabinose, and others.",
#   "Plant part used": "Seeds, roots, shoots, and fruits.",
#   "Formulation": "The formulations include essential oil, fixed oil, aqueous extract, methanolic extract, ethanol extract, chloroform extract, ethyl acetate extract, hydrodistillated oil, supercritical carbon dioxide extract, tablets, capsules, tinctures, and powder.",
#   "Botanic description": "Nigella sativa is an erect, herbaceous flowering plant with a stiff and multi-branched stem and a well-developed taproot. It grows to a height of 30–70 cm, with angular stems. The leaves are alternate, linear to lanceolate, measuring 2.5–5.0 cm in length and 2.0–2.5 cm in width. Flowers are pink, white, yellow, pale blue, or pale purple, with 5–10 petals and 4–6 sepals. Seeds are black, ovate, tetrangular, and more tapering at the end, sized approximately 2.33 mm × 1.14 mm.",
#   "Toxicity": "Thymoquinone, the main constituent, appears to have low toxicity after oral administration. High values of oral and intraperitoneal lethal doses of Nigella sativa fixed oil indicate its low acute toxicity. However, subacute toxicity evaluations showed no toxicity, while chronic toxicity studies found slightly toxic effects at 2 ml/kg NS fixed oil.",
#   "Adverse reactions": "Not mentioned.",
#   "Health Benefits": "Nigella sativa is known to balance Vata (movement energy) and Kapha (structure and lubrication energy), increase Pitta (metabolism or digestion energy), act as stomachic, laxative, carminative, galactagogue, counter inflammation, ascites, jaundice, piles, tertian fever, paralysis, and eye diseases. It is also used for combating headaches, cough and asthma, expelling kidney stones, freshening breath, controlling parasitic infections, diuretic, emmenagogue, insect repellent, liver tonic, and skin infections.",
#   "Nutritional benefits": "Nigella sativa contains 21% protein, 35.5% fat, 5.5% moisture, 3.7% ash, carbohydrates (rhamnose, xylose, and arabinose), polyunsaturated fatty acids (PUFA), and phytosterols. Oleic acid and linoleic acid modulate cardiac glycosides interaction with the sodium pump.",
#   "Reference": "Hossain, M. S., Sharfaraz, A., Dutta, A., Ahsan, A., Masud, M. A., Ahmed, I. A., Goh, B. H., Urbi, Z., Sarker, M. M. R., & Ming, L. C. (2021). A review of ethnobotany, phytochemistry, antimicrobial pharmacology and toxicology of Nigella sativa L. Biomedicine & Pharmacotherapy, 143, 112182. https://doi.org/10.1016/j.biopha.2021.112182"
# }
# ```
# 10
# ```json
# {
#   "Title": "Nigella sativa and health outcomes: An Overview of Systematic Reviews and Meta-Analyses",
#   "Authors": "Zhongyu Li, Yang Wang, Qing Xu, Jinxin Ma, Xuan Li, Jiaxing Yan, Yibing Tian, Yandong Wen, Ting Chen",
#   "Year": 2023,
#   "Scientific name of Medicinal plant": "Nigella sativa",
#   "Medicinal use": "Used for respiratory, digestive, and cardiovascular diseases, such as asthma, dyspepsia, and hypertension, and to improve liver and kidney function.",
#   "Biological activity": "Demonstrates antiviral, anti-inflammatory, hypotensive, hypoglycemic, and antitumor effects. These activities are attributed to the presence of phytochemicals like thymoquinone, terpenes, saponins, flavonoids, and essential oils.",
#   "Dose": "Dosages range from 0.5 to 6 g or 2.5 to 5 ml daily, with frequencies varying from once to thrice a day.",
#   "Phytochemicals": "Thymoquinone, terpenes, saponins, flavonoids, essential oils",
#   "Plant part used": "Seeds",
#   "Formulation": "Capsules, oils, powders, extracts",
#   "Botanic description": "Not mentioned",
#   "Toxicity": "Not mentioned",
#   "Adverse reactions": "Digestive symptoms such as stomach pain, diarrhea, nausea, vomiting, weakness, and weight loss were reported. No serious adverse events were noted.",
#   "Health Benefits": "Potential benefits include improved blood glucose control, lipid profiles, blood pressure, inflammatory markers, oxidative stress factors, body composition, liver and kidney parameters, and asthma indicators.",
#   "Nutritional benefits": "Not mentioned",
#   "Reference": "Li, Z., Wang, Y., Xu, Q., Ma, J., Li, X., Yan, J., Tian, Y., Wen, Y., & Chen, T. (2023). Nigella sativa and health outcomes: An overview of systematic reviews and meta-analyses. Frontiers in Nutrition, 10, 1107750. https://doi.org/10.3389/fnut.2023.1107750"
# }
# ```
# 11
# ```json
# {
#   "Title": "Nigella sativa: A Comprehensive Review of Its Therapeutic Potential, Pharmacological Properties, and Clinical Applications",
#   "Authors": "Adina Alberts, Elena-Theodora Moldoveanu, Adelina-Gabriela Niculescu, Alexandru Mihai Grumezescu",
#   "Year": "2024",
#   "Scientific name of Medicinal plant": "Nigella sativa",
#   "Medicinal use": "Used to treat gastrointestinal, respiratory, cardiovascular, infectious, inflammatory conditions, diabetes, hypertension, cancer, rheumatism, back pain, diarrhea, skin conditions, analgesics, liver tonic, anti-diarrhea, antibacterial, anti-inflammatory agent, diuretic.",
#   "Biological activity": "Antioxidant, anti-inflammatory, antimicrobial, immunomodulatory, antitumoral, hepatoprotective, neuroprotective, nephroprotective, gastroprotective, antidiabetic, hypotensive, hypolipidemic, anticonvulsant, antidepressant, antianxiety, antipsychotic, memory improvement, spasmolytic, bronchodilator effects.",
#   "Dose": "1.5–3 mL/day of NS oil for 20 days in diabetic patients; 1–3 g/day of NS seeds for T2DM patients; 2 g/day of NS seeds for H. pylori-induced gastric ulcers; 2.5 mL of NS oil for hypertensive patients; 5 mL/day of NS for volunteers for 26 days; 2 g/day of NS seeds for obesity; 0.5–2 g of NS powder in capsules for immune response studies.",
#   "Phytochemicals": "Thymoquinone, p-cymene, α-thujene, longifolene, β-pinene, α-pinene, carvacrol, limonene, α-terpineol, gallic acid, kaempferol, quercetin, α-hederin, trans-anethole, dithymoquinone, thymohydroquinone, thymol.",
#   "Plant part used": "Seeds, roots, shoots",
#   "Formulation": "Essential oils, powders, pills, extracts, capsules, tablets, nasal oil drops, oral supplements, balm sticks, fixed oil, aqueous extract, hydrophilic biodegradable polymers (e.g., polyethylene glycol), nanostructured lipid carriers.",
#   "Botanic description": "Nigella sativa is an annual herb growing to a height of 20–30 cm with linear leaves, light blue and white flowers forming a large, swollen capsule containing the seeds.",
#   "Toxicity": "Low toxicity at therapeutic doses but higher doses can cause behavioral abnormalities, restlessness, somnolence, liver damage, hematological changes. Chronic administration may affect platelets and leukocytes.",
#   "Adverse reactions": "Minor adverse effects such as nasal dryness and itching reported in some studies but generally temporary and statistically insignificant.",
#   "Health Benefits": "Improves glucose homeostasis, lipid profile, gastrointestinal and hepatic protection, antitussive, cardioprotective, antihypertensive effects, antioxidant, anti-inflammatory, antimicrobial, immunomodulatory properties, neuroprotection, memory enhancement.",
#   "Nutritional benefits": "Rich in proteins, minerals (iron, calcium, potassium, magnesium, zinc, copper), vitamins A and C, phytochemicals, sterols, saponins, phenolic compounds, alkaloids, lipid constituents, fatty acids (linoleic, linolenic, oleic, palmitoleic, palmitic, arachidonic, stearic acids).",
#   "Reference": "Alberts, A., Moldoveanu, E.-T., Niculescu, A.-G., & Grumezescu, A. M. (2024). Nigella sativa: A Comprehensive Review of Its Therapeutic Potential, Pharmacological Properties, and Clinical Applications. International Journal of Molecular Sciences, 25(24), 13410. https://doi.org/10.3390/ijms252413410"
# }
# ```
# 12
# ```json
# {
#   "Title": "Protective Effect of Nigella sativa Seeds Against Spermatocyte Chromosomal Aberrations and Genotoxicity Induced by Carbon Tetrachloride in Mice",
#   "Authors": "Ashraf M. Abdel-Moneim, Amina E. Essawy, Sherifa S. Hamed, Ashgan A. Abou-Gabal, Aglal A. Alzergy",
#   "Year": "2017",
#   "Scientific name of Medicinal plant": "Nigella sativa",
#   "Medicinal use": "Used to prevent chromosomal aberrations and genotoxicity induced by carbon tetrachloride in mice.",
#   "Biological activity": "The biological activities include antioxidant, anti-inflammatory, anthelminthic, antimicrobial, antidiabetic, and antineoplastic properties. It also has the ability to protect against DNA/chromosomal damage, reduce clastogenic activity, and alleviate testicular tissue damage.",
#   "Dose": "50 mg/kg body weight of aqueous suspension of N. sativa seeds administered orally every other day for three successive weeks.",
#   "Phytochemicals": "Thymoquinone (TQ), carvacrol, t-anethole, 4-terpinol, nigellidine, nigellicine, nigellicimine, nigellicimine-N-oxide, alpha-hederin, saponin, riboflavin, thiamin, niacin, pyridoxine, folic acid, vitamin E, potassium, sodium, calcium, phosphorus, magnesium, copper, iron.",
#   "Plant part used": "Seeds",
#   "Formulation": "Aqueous suspension prepared with 1.25 g N. sativa powder + 100 ml isotonic saline.",
#   "Botanic description": "Not mentioned",
#   "Toxicity": "High concentrations of seed oil fractions, especially thymoquinone, can initiate in vivo and in vitro cytotoxicity. However, N. sativa extracts are practically nontoxic to mice and rats in acute oral administration.",
#   "Adverse reactions": "Not mentioned",
#   "Health Benefits": "N. sativa is effective in counteracting CCl4-induced genetic damage to germ cells and may be used as an adjunct dietary supplement during the initial phases of exposure to mutagens.",
#   "Nutritional benefits": "Rich in polyunsaturated fatty acids, phytosterols, vitamins, and minerals.",
#   "Reference": "Abdel-Moneim, A. M., Essawy, A. E., Hamed, S. S., Abou-Gabal, A. A., & Alzergy, A. A. (2017). Protective effect of Nigella sativa seeds against spermatocyte chromosomal aberrations and genotoxicity induced by carbon tetrachloride in mice. Environmental Science and Pollution Research, 24, 11677–11682. https://doi.org/10.1007/s11356-017-8806-y"
# }
# ```
# 13
# ```json
# {
#   "Title": "A Comprehensive Review on Chemical Profile and Pharmacological Activities of Ocimum basilicum",
#   "Authors": "Kuldeep Dhama, Khan Sharun, Mudasir B. Gugjoo, Ruchi Tiwari, Mahmoud Alagawany, Mohd. Iqbal Yatoo, Pallavi Thakur, Hafiz M.N. Iqbal, Wanpen Chaicumpa, Izabela Michalak, Shaaban S. Elnesr, Mayada R. Farag",
#   "Year": "2021",
#   "Scientific name of Medicinal plant": "Ocimum basilicum",
#   "Medicinal use": "Used for treating various ailments including antimicrobial, antifungal, insecticidal, antiparasitic, antioxidant, immunomodulatory, anti-inflammatory, hepatoprotective, anti-osteoporotic, cardioprotective, neuroprotective, anti-cancer, larvicidal, insecticidal, anti-neoplastic, hypoglycemic, hypolipidemic, and analgesic effects.",
#   "Biological activity": "The biological activities include antimicrobial (against bacteria, fungi, viruses, and parasites), anti-inflammatory, antioxidant, immunomodulatory, anticancer, anti-ulcer, cardioprotective, hepatoprotective, hypoglycemic, hypolipidemic, neuroprotective, sedative, anti-depressant, and anti-convulsant properties.",
#   "Dose": "Not mentioned",
#   "Phytochemicals": "Linalool, geraniol, methyl eugenol, methyl chavicol, p-allylanisole, 1,8–cineole, trans–α–bergamotene, neryl acetate, estragole, rosmarinic acid, apigenin, diosmetin, caffeic acid, 3,4-dimethoxycinnamic acid, genistein, kaempferol, luteolin, ursolic acid, eugenol, isoeugenol, terpinolene",
#   "Plant part used": "Leaves, seeds, roots, aerial parts, flowers",
#   "Formulation": "Extracts (aqueous, methanolic, hydroethanolic, ethanolic), essential oils, nanoparticles, nanoemulsion, mucilage from seeds",
#   "Botanic description": "Not mentioned",
#   "Toxicity": "No toxicity observed up to a dose of 5000 mg/kg in rats; contains carcinogenic compounds like safrole and quercetin at negligible levels.",
#   "Adverse reactions": "Not mentioned",
#   "Health Benefits": "Antioxidant, anti-inflammatory, antimicrobial, antiviral, anti-fungal, anti-cancer, anti-diabetic, cardio-protective, hepatoprotective, neuroprotective, anti-depressant, anti-convulsant, sedative, anti-ulcer, anti-osteoporotic, hypoglycemic, hypolipidemic, and immunomodulatory effects.",
#   "Nutritional benefits": "Rich in vitamins (C, E, K, A, β-carotene, B1, B2, B3, B5, B6, B9) and minerals (Fe, Ca, Mg, P, Mn, Na, K, Zn); also contains secondary metabolites such as essential oils, phenols, flavonoids, anthocyanins, tannins, and steroids.",
#   "Reference": "Dhama, K., Sharun, K., Gugjoo, M. B., Tiwari, R., Alagawany, M., Yatoo, M. I., ... & Farag, M. R. (2021). A Comprehensive Review on Chemical Profile and Pharmacological Activities of Ocimum basilicum. Food Reviews International, 1-30. https://doi.org/10.1080/87559129.2021.1900230"
# }
# ```
# 14
# ```json
# {
#   "Title": "Sweet Basil (Ocimum basilicum L.)—A Review of Its Botany, Phytochemistry, Pharmacological Activities, and Biotechnological Development",
#   "Authors": "Nabilah Sekar Azizah, Budi Irawan, Joko Kusmoro, Wahyu Safriansyah, Kindi Farabi, Dina Oktavia, Febri Doni, Mia Miranti",
#   "Year": 2023,
#   "Scientific name of Medicinal plant": "Ocimum basilicum L.",
#   "Medicinal use": "Traditionally used for treating flu, fever, colds, digestive issues, reproductive health, respiratory conditions, malaria, rheumatism, high cholesterol, hypertension, headaches, stroke, diabetes, cancer, neuroprotection, antiviral, antibacterial, antifungal, antioxidant, anti-inflammatory, antidepressant, wound healing, and more.",
#   "Biological activity": "The plant exhibits antiviral, antibacterial, antifungal, antioxidant, anticancer, antidiabetic, analgesic, neuroprotective, and anti-inflammatory activities. Compounds like carvacrol, eugenol, linalool, estragole, citral, α-pinene, nerolidol, kaempferol, and trans-α-bergamotene are active against bacteria and fungi. Polyphenols such as rutin, apigenin, and quercetin inhibit fungal enzymes. Eugenol, ursolic acid, and stigmasterol have shown potential in antiviral drug development.",
#   "Dose": "Not mentioned",
#   "Phytochemicals": "Linalool, eugenol, estragole, eucalyptol, geraniol, myrtenol, pinene, camphor, borneol, caffeic acid, caftaric acid, 3,4-dihydroxyphenylacetic acid, ferulic acid, rosmarinic acid, rutoside (rutin), β-sitosterol, stigmasterol, campesterol, α-pinene, β-myrcene, citral, camphene, terpineol, linalyl acetate, cis-Sabinene hydrate, (-)-trans-Pinocarvyl acetate, limonene dioxide, geraniol, carvone, methyl eugenol, fenchone, l-Menthol, trans-linalool oxide, cis-Linalool-oxide, neral, 1,8-cineole (Eucalyptol), methyl cinnamate, copaene, neoisolongifolene, α-bergamotene, trans-α-bergamotene, β-farnesene, alloaromadendrene, γ-Cadinene, humulene, α-Humulene, α-Copaene, β-Copaene, β-Bisabolene, cis-muurola-3,5-diene, cis-α-Bisabolene, α-Cubebene, germacrene B, germacrene D, β-Elemene, β-Cubebene, β-Caryophyllene, α-Bisabolol, α-Cadinol, nerolidol, caryophyllene oxide, trans-4-Methoxycinnamaldehyde, mandelic acid, phenylethanolamine, N-Benzyl-N-ethyl-p-isopropylbenzamide, cis-2-(2-pentenyl) furan, α-guaiene, sitosterol, apigenin, ursolic acid, inositol, 5,7-dihydroxy-3′,4′,5′-trimethoxyflavone, 3-hydroxy-3′,4′,5′-trimethoxyflavone.",
#   "Plant part used": "Leaves, seeds, aerial parts, flowers, fruits, stems, inflorescence",
#   "Formulation": "Essential oil, methanolic extracts, hydrodistillation, maceration, solvent-free microwave extraction, emulgel formulation, hydrogel, nanoparticles, topical ointment",
#   "Botanic description": "Sweet basil is an annual herb with dense foliage and aromatic components. It grows up to 0.6 m in height, with lateral branches forming angles over 30° with the main branch. The stem is round-quadrangular, glabrous or puberulent. Leaves are green, ovate or elliptic ovate, with serrated margins. Flowers are white or pinkish, funnel-shaped. Fruits produce mucilage upon interaction with water.",
#   "Toxicity": "Not mentioned",
#   "Adverse reactions": "Not mentioned",
#   "Health Benefits": "Antioxidant, anticancer, antidiabetic, neuroprotective, anti-inflammatory, wound healing, antimicrobial properties contribute to overall health benefits.",
#   "Nutritional benefits": "Rich in phenolic compounds, flavonoids, and terpenes, which provide antioxidant and anti-inflammatory benefits.",
#   "Reference": "Azizah, N. S., Irawan, B., Kusmoro, J., Safriansyah, W., Farabi, K., Oktavia, D., Doni, F., & Miranti, M. (2023). Sweet Basil (Ocimum basilicum L.)—A Review of Its Botany, Phytochemistry, Pharmacological Activities, and Biotechnological Development. Plants, 12(24), 4148. https://doi.org/10.3390/plants12244148"
# }
# ```
# 15
# ```json
# {
#   "Title": "Ocimum Basilicum: A Review on Phytochemical and Pharmacological Studies",
#   "Authors": "S. Khair-ul-Bariyah, D. Ahmed, M. Ikram",
#   "Year": 2012,
#   "Scientific name of Medicinal plant": "Ocimum basilicum",
#   "Medicinal use": "Used for digestive and nervous disorders, anthelmintic, antipyretic, stomachic, taste improving agent, cardioprotective, cure for blood diseases, muscle cramps, insecticidal, diabetes, respiratory disorders, antioxidant, anti-inflammatory, feverish illness, nausea, migraine, abdominal cramps, gonorrhea, dysentery, headache, colic, dizziness, piles, cough, paralysis, nervous temperament, numbness, acne, snake bites, insect stings, diarrhea, vomiting, constipation, mental fatigue.",
#   "Biological activity": "Immunomodulatory, antioxidant, antihyperglycemic, hypolipidemic, anti-herpes simplex virus, anti-inflammatory, hepatoprotective, lipid peroxidation inhibition, insect repellent, larvicidal, central nervous system protection, anticonvulsant, antimicrobial, antifungal, antimutagenic, antierythmic, depigmenting, antitoxic.",
#   "Dose": "Not mentioned.",
#   "Phytochemicals": "Terpenoids, alkaloids, flavonoids, tannins, saponin glycosides, ascorbic acid, chicoric acid, caffeic acid derivatives, phenolic acids, flavonol-glycosides, linalool, geraniol, 1,8-cineole, β-myrcene.",
#   "Plant part used": "Leaves, flowering tops, essential oil, seeds.",
#   "Formulation": "Topical cream with 3% concentrated extract of basil, aqueous extract, methanolic extract, ethanol extract, hexane extract.",
#   "Botanic description": "A herb of medium size with strong scent, smooth or velvety touch. Leaves are opposite, simple, entire, ovate, toothed, 3-5 cm long with slender petioles. Flowers are 8-12 mm long in cluster-like circles of 6-10 flowers, petals can be white, pink, or purplish. Glandular and non-glandular hair found on both sides of the leaves. Seeds are black and oval.",
#   "Toxicity": "Not mentioned.",
#   "Adverse reactions": "Not mentioned.",
#   "Health Benefits": "Antioxidant, anti-inflammatory, hepatoprotective, immunomodulatory, antihyperglycemic, hypolipidemic, antimicrobial, antifungal, insect repellent, larvicidal, antidepressant, anticonvulsant, antitoxic, antierythmic, depigmenting.",
#   "Nutritional benefits": "Contains potassium, calcium, sodium, magnesium.",
#   "Reference": "Khair-ul-Bariyah, S., Ahmed, D., & Ikram, M. (2012). Ocimum Basilicum: A Review on Phytochemical and Pharmacological Studies. Pakistan Journal of Chemistry, 2(2), 78-85. https://doi.org/10.15228/2012.v02.i02.p05"
# }
# ```
# 16
# ```json
# {
#   "Title": "A Comprehensive Review on Ocimum basilicum",
#   "Authors": "Balakrishnan Purushothaman, Ramalingam PrasannaSrinivasan, Suganthi Purushothaman, Balu Ranganathan, Jolius Gimbun, Kumaran Shanmugam",
#   "Year": "2018",
#   "Scientific name of Medicinal plant": "Ocimum basilicum",
#   "Medicinal use": "Used as a culinary herb, traditional medicine for treating various ailments such as diabetes, cardiovascular disorders, menstrual cramps, digestive disorders, neuro-degenerated disorders, and cancer. Also used in perfumery, cosmetics, and food industries.",
#   "Biological activity": "The plant exhibits anticonvulsant, anti-hyperlipidemic, anti-inflammatory, antioxidant, antiplatelet, anti-thrombotic, antimicrobial, insecticidal, immunomodulatory, and cytotoxic activities. It also acts against neuro-degenerated and digestive disorders, and has spasmolytic, carminative, hepatoprotective, diuretic, and stimulating properties.",
#   "Dose": "Not mentioned",
#   "Phytochemicals": "Linalool, eugenol, 1,8-cineole, methyl eugenol, limonene, β-elemene, α-bergamotene, bornyl acetate, menthol, camphor, α-copaene, β-caryophyllene, chicoric acid, farnesene, β-cadinene, menthyl acetate, germacrene, α-bisabolol, δ-gurjunene, δ-cadinene, estragole, neo isomenthol, guaiene, pulegone",
#   "Plant part used": "Leaves, flowers, seeds, aerial parts",
#   "Formulation": "Extracts (aqueous, methanolic), essential oils, powder from leaves, hydrodistillation, solvent extraction, GC-MS analysis, HPLC separation",
#   "Botanic description": "Not mentioned",
# ...
#   "Adverse reactions": "Stomach upset, diarrhea, bloating, signs of low blood sugar (nervousness, shakiness, fast heartbeat, sweating), allergic reactions (rash, itching/swelling, severe dizziness, trouble breathing), potential teratogenic effects at high doses.",
#   "Health Benefits": "Regulates glucose levels, reduces lipid levels, prevents secondary diabetic complications, exhibits antioxidant properties, protects liver and kidney function, shows anti-inflammatory effects, enhances insulin sensitivity, and improves reproductive system health in diabetic conditions.",
#   "Nutritional benefits": "Rich in dietary fiber (soluble and insoluble), amino acids, fatty acids, vitamins, saponins, flavonoids, polysaccharides, fixed oils, alkaloids, enhancing the nutritional value of diets when supplemented.",
#   "Reference": "Yadav, U. C. S., & Baquer, N. Z. (2014). Pharmacological effects of Trigonella foenum-graecum L. in health and disease. Pharmaceutical Biology, 52(2), 243–254. https://doi.org/10.3109/13880209.2013.826247"
# }
# ```
# 60
# ```json
# {
#   "Title": "Therapeutic Role of Trigonella Foenum-Graecum [Fenugreek] - A Review",
#   "Authors": "Nathiya S, Durga M, Devasena T",
#   "Year": 2014,
#   "Scientific name of Medicinal plant": "Trigonella foenum-graecum",
#   "Medicinal use": "Used traditionally for treating arthritis, asthma, bronchitis, improving digestion, increasing libido and male potency, curing skin problems, treating sore throat, acid reflux, reproductive disorders, inducing labor, treating hormonal disorders, breast enlargement, reducing menstrual pain, blood sugar regulation, anti-inflammatory, anti-toxic, anti-cancer, hypoglycemic, hypercholesterolemia, gastroprotective, chemo-preventive, antioxidant, laxative, appetite stimulation, anti-cataract, immunomodulatory activity.",
#   "Biological activity": "The biological activities include anti-diabetic activity by delaying carbohydrate digestion and absorption, enhancing insulin action; hypocholesterolaemic properties through reduction in plasma cholesterol levels; immunomodulatory activity by stimulating macrophages and lymphocytes; anti-cataract activity by restoring glutathione and decreasing malondialdehyde levels; and antioxidant activity by scavenging free radicals and inhibiting lipid peroxidation.",
#   "Dose": "Dosages mentioned include: SDF fraction (0.5 g/kg body weight), fenugreek whole seed powder (5% in the diet), aqueous extract (50, 100, 250 mg/kg body weight), fenugreek seeds mucilage (4 mg/100 g body weight per day).",
#   "Phytochemicals": "Steroids, N-compounds, polyphenolic substances, volatile constituents, amino acids, galactomannans, proteins, lipids, pyridine alkaloids, trigonelline, choline, carpaine, gentianine, flavonoids (luteolin, apigenin, quercetin, orientin, isovitexin, vitexin), 4-hydroxyisoleucine, histidine, arginine, lysine, calcium, saponins, glycosides, steroidal sapogenins (yamogenin, diosgenin, neotigogenin, tigogenin), sitosterol, cholesterol, vitamin A, B1, C, nicotinic acid.",
#   "Plant part used": "Seeds",
#   "Formulation": "Soluble dietary fiber fraction, aqueous extract, ethanol extract, defatted seeds, mucilage, powder, standardized extract.",
#   "Botanic description": "Not mentioned",
#   "Toxicity": "Minor side effects such as nausea and gastrointestinal discomfort (diarrhea and/or gas) are reported.",
#   "Adverse reactions": "Nausea, gastrointestinal discomfort (diarrhea and/or gas)",
#   "Health Benefits": "Improves glucose homeostasis, reduces oxidative stress, protects against pesticide-induced toxicity, enhances immune function, mitigates lipid abnormalities, prevents collagen cross-linking, reduces cataract formation, modulates acetylcholinesterase activity, increases hemoglobin levels, and promotes digestive health.",
#   "Nutritional benefits": "Rich in proteins, mucilaginous fiber, vitamins, minerals, and other bioactive compounds that contribute to overall health.",
#   "Reference": "S, Nathiya, Durga M, Devasena T. Therapeutic role of Trigonella foenum-graecum [fenugreek] - A review. International Journal of Pharmaceutical Sciences Review and Research. 2014;27(2):74-80. https://www.globalresearchonline.net/journal_contents_new.asp?idj=3&idn=27"
# }
# ```
# 61
# ```json
# {
#   "Title": "Review Fenugreek (Trigonella foenum-graecum): Nutraceutical values, phytochemical, ethnomedicinal and pharmacological overview",
#   "Authors": "Pushpa Ruwalia, Niharika Pandeya, Khusboo Jindala, Rahul Vikram Singhb",
#   "Year": "2022",
#   "Scientific name of Medicinal plant": "Trigonella foenum-graecum",
#   "Medicinal use": "Used for treating diabetes, hypertension, atherosclerosis, cardiovascular diseases, cancer, obesity, asthma, neurological disorders, promoting hair growth, gastroprotective activity, increasing breast milk supply, enhancing male testosterone levels.",
#   "Biological activity": "Fenugreek exhibits anti-biotic, anti-oxidant, anti-carcinogenic, hypoglycemic, hypocholesterolemic, anti-fungal, anti-bacterial, and anti-inflammatory activities. It also promotes hair growth, protects against gastric ulcers, and enhances lactation.",
#   "Dose": "Not mentioned",
#   "Phytochemicals": "Alkaloids, flavonoids, saponins, fibers, fatty acids, carbohydrates, steroidal sapogenins, proteins, amino acids, vitamins, minerals",
#   "Plant part used": "Seeds, leaves, husk, endosperm",
#   "Formulation": "Tea, powder, extract, seed flour, aqueous extract, hydroalcoholic extract, gum",
#   "Botanic description": "Fenugreek is an erect, branched herb growing up to 30–60 cm in height. It has trifoliate, pinnate leaves, root nodules, white to yellow flowers, thin pointed pods (3–15 cm long), and golden yellow seeds.",
#   "Toxicity": "Not mentioned",
#   "Adverse reactions": "Not mentioned",
#   "Health Benefits": "Improves glucose metabolism, reduces cholesterol levels, inhibits cancer cell growth, suppresses hunger aiding in weight loss, alleviates asthma symptoms, provides neuroprotection, promotes hair growth, protects against gastric ulcers, increases breast milk production, boosts testosterone levels.",
#   "Nutritional benefits": "Rich in dietary fiber, protein, vitamins, and minerals. Acts as a probiotic in functional food and enhances nutritional value when added to bakery products.",
#   "Reference": "Ruwali, P., Pandey, N., Jindal, K., & Singh, R. V. (2022). Review Fenugreek (Trigonella foenum-graecum): Nutraceutical values, phytochemical, ethnomedicinal and pharmacological overview. South African Journal of Botany, 151, 423-431. https://doi.org/10.1016/j.sajb.2022.04.014"
# }
# ```
# 62
# ```json
# {
#   "Title": "Analgesic And Anti-Inflammatory Activities Of Trigonella Foenum-Graecum (Seed) Extract",
#   "Authors": "Savita Vyas, Rajendra Prasad Agrawal, Pooja Solanki, Piyush Tripathi",
#   "Year": 2008,
#   "Scientific name of Medicinal plant": "Trigonella foenum-graecum",
#   "Medicinal use": "Treatment of pain and inflammation, traditionally used for rheumatism.",
#   "Biological activity": "The partially purified fraction (MTH) from Trigonella foenum-graecum seed extract exhibits significant analgesic and anti-inflammatory activities. The analgesic effect was demonstrated in both thermally and chemically induced pain models, while the anti-inflammatory potential was shown in carrageenan-induced rat paw edema.",
#   "Dose": "For analgesic studies: 10-40 mg/kg p.o.; For anti-inflammatory studies: 10-20 mg/kg i.p.",
#   "Phytochemicals": "Glycoside, steroid, saponins (in seeds), alkaloids, cardiac glycosides, phenols (in leaves).",
#   "Plant part used": "Seeds",
#   "Formulation": "Partially purified fraction (MTH) obtained from methanolic extraction of seeds, dissolved in distilled water for administration.",
#   "Botanic description": "Not mentioned",
#   "Toxicity": "Not mentioned",
#   "Adverse reactions": "No gross behavioral changes, sedation, morbidity, or mortality observed at tested doses.",
#   "Health Benefits": "Significant analgesic and anti-inflammatory effects, suggesting potential use in pain and inflammation management.",
#   "Nutritional benefits": "Not mentioned",
#   "Reference": "Vyas, S., Agrawal, R. P., Solanki, P., & Tripathi, P. (2008). Analgesic and anti-inflammatory activities of Trigonella foenum-graecum (seed) extract. Acta Poloniae Pharmaceutica - Drug Research, 65(4), 473-476."
# }
# ```
# 63
# ```json
# {
#   "Title": "Fenugreek (Trigonella foenum-graecum): A Review of Health Beneficial Physiological Effects",
#   "Authors": "K. Srinivasan",
#   "Year": 2006,
#   "Scientific name of Medicinal plant": "Trigonella foenum-graecum",
#   "Medicinal use": "Used as an antibacterial, gastric stimulant, against anorexia, antidiabetic agent, and galactagogue.",
#   "Biological activity": "The biological activities include antidiabetic effect, hypocholesterolemic influence, antioxidant potency, digestive stimulant action, and hepatoprotective effect.",
#   "Dose": "Dosages range from 15g/day for NIDDM patients to 100g/day in clinical trials. Single doses of 0.5g/kg body weight have also been used in animal studies.",
#   "Phytochemicals": "Saponins, alkaloids (including trigonelline), steroidal saponins (diosgenin), flavonoids, galactomannan, and 4-hydroxyisoleucine.",
#   "Plant part used": "Seeds and leaves are primarily used for medicinal purposes.",
#   "Formulation": "Fenugreek is used in the form of powder, decoction, aqueous/methanolic/ethanolic extracts, defatted seeds, gum isolate, and germinated seeds.",
#   "Botanic description": "Fenugreek is a leguminous herb that grows up to 30–60 cm tall with compound pinnate trifoliate leaves, axillary white to yellowish flowers, and long thin pointed beaked pods containing oblong greenish-brown seeds.",
#   "Toxicity": "Not mentioned.",
#   "Adverse reactions": "Fenugreek extract and leaf must be contraindicated in women during early pregnancy to avoid risk of fetal loss and during menstruation to reduce the risk of excessive bleeding.",
#   "Health Benefits": "Antidiabetic, hypocholesterolemic, antioxidant, digestive stimulant, gastroprotective, hepatoprotective, immunomodulatory, and anti-hyperthyroidic effects.",
#   "Nutritional benefits": "Rich in dietary fiber, protein, vitamins (especially choline), and minerals such as calcium, magnesium, phosphorus, iron, potassium, copper, sulfur, chlorine, manganese, zinc, and chromium.",
#   "Reference": "Srinivasan, K. (2006). Fenugreek (Trigonella foenum-graecum): A Review of Health Beneficial Physiological Effects. Food Reviews International, 22(2), 203-224. https://doi.org/10.1080/87559120600586315"
# }
# ```
# 64
# ```json
# {
#   "Title": "Anti-Inflammatory and Antipyretic Effects of Trigonella Foenum-Graecum Leaves Extract in the Rat",
#   "Authors": "A. Ahmadiani, M. Javan, S. Semnanian, E. Barat, M. Kamalinejad",
#   "Year": "2001",
#   "Scientific name of Medicinal plant": "Trigonella foenum-graecum",
#   "Medicinal use": "The leaves extract of Trigonella foenum-graecum is used for its anti-inflammatory and antipyretic properties.",
#   "Biological activity": "The extract exhibits potent anti-inflammatory activity by inhibiting rat paw inflammation induced by formalin, both in single dose and chronic applications. It also shows significant antipyretic effects by reducing yeast-induced hyperthermia.",
#   "Dose": "Single dose: TFG 500, 1000, and 2000 mg/kg (i.p.), 1000 mg/kg (p.o.). Chronic administration: TFG 1000 mg/kg daily for 7 days.",
#   "Phytochemicals": "Alkaloids, cardiac glycosides, phenols, trace amounts of steroids.",
#   "Plant part used": "Leaves",
#   "Formulation": "Decoction of dried leaves in water, concentrated to a honey-like viscosity.",
#   "Botanic description": "Not mentioned",
#   "Toxicity": "No acute toxicity was observed with chronic administration of the extract over 7 days.",
#   "Adverse reactions": "Not mentioned",
#   "Health Benefits": "The extract has potential health benefits as an anti-inflammatory and antipyretic agent.",
#   "Nutritional benefits": "Not mentioned",
#   "Reference": "Ahmadiani, A., Javan, M., Semnanian, S., Barat, E., & Kamalinejad, M. (2001). Anti-inflammatory and antipyretic effects of Trigonella foenum-graecum leaves extract in the rat. Journal of Ethnopharmacology, 75(2–3), 283–286. https://doi.org/10.1016/S0378-8741(01)00187-8"
# }
# ```
# 65
# ```json
# {
#   "Title": "A Small Plant with Big Benefits: Fenugreek (Trigonella foenum-graecum Linn.) for Disease Prevention and Health Promotion",
#   "Authors": "Kalyan C. Nagulapalli Venkata, Anand Swaroop, Debasis Bagchi, Anupam Bishayee",
#   "Year": "2017",
#   "Scientific name of Medicinal plant": "Trigonella foenum-graecum Linn.",
#   "Medicinal use": "Fenugreek is used as an antidiabetic, antihyperlipidemic, antiobesity, anticancer, anti-inflammatory, antioxidant, antifungal, antibacterial, galactogogue, sexual health-modulating agent, and for miscellaneous pharmacological effects including improving women's health.",
#   "Biological activity": "Fenugreek exhibits antioxidative, anti-inflammatory, antimicrobial, antidiabetic, antihyperlipidemic, antiobesity, anticancer, hepatoprotective, and sexual health-promoting biological activities. These activities are attributed to its diverse array of phytoconstituents that modulate various cellular and molecular mechanisms.",
#   "Dose": "Clinical studies indicate doses ranging from 25 g/day of fenugreek seed powder for 24 weeks in diabetic patients, 1–5 g/kg body weight in rats, and LD50 values of 5–10 g/kg body weight depending on the extract type and route of administration.",
#   "Phytochemicals": "Steroids, alkaloids, saponins, polyphenols, flavonoids, lipids, carbohydrates, amino acids, hydrocarbons, trigoneosides, protodioscin, diosgenin, yamogenin, trigonelline, 4-hydroxyisoleucine, sotolone, galactomannan, quercetin, luteolin, vitexin, kaempferol, tricin, naringenin, apigenin-6-C-glucoside, apigenin-8-C-glucoside, vicenin-1, vicenin-2, p-coumaric acid, caffeic acid, chlorogenic acid, hymecromone, trigoforin, trigocoumarin, scopoletin, α-schizandrin, zingerone, vanillin, gingerol, eugenol, cedrene, N-linoleoyl-2-amino-β-butyro lactone.",
#   "Plant part used": "Seeds, leaves, endosperm, whole plant, aerial parts, flowers, and stems.",
#   "Formulation": "Extracts (aqueous, ethanolic, methanolic), seed powder, galactomannan gum, debitterized fenugreek powder, nano-formulations, and liposomal drug delivery systems.",
#   "Botanic description": "Fenugreek is a short-living annual plant belonging to the Fabaceae family. It attains a height of 1–2 feet, bears green trifoliate leaves, white to yellow flowers, and thin pods about 15 cm in length containing 10–20 seeds. The seeds are golden yellow with an average height of 4.01–4.19 mm, width of 2.35–2.60 mm, and thickness of 2.40–2.66 mm.",
#   "Toxicity": "Fenugreek is generally recognized as safe (GRAS) by regulatory authorities. Toxicological studies show no genotoxicity or significant toxicity at tested doses. However, caution is advised for individuals allergic to chickpeas due to potential cross-reactivity.",
#   "Adverse reactions": "Minor adverse events such as increased incidences of migraines and indigestion were reported in some clinical trials. Pregnant women should exercise caution due to possible abortifacient effects at higher doses.",
#   "Health Benefits": "Fenugreek improves glycemic control, reduces hyperlipidemia, alleviates obesity, enhances sexual function, promotes women's health, protects against oxidative stress, and exerts anti-inflammatory and antimicrobial effects.",
#   "Nutritional benefits": "Rich in vitamins A, B1, B2, C, niacin, nicotinic acid, calcium, β-carotene, folic acid, essential minerals like Fe, Ca, P, S, Mg, Co, Cu, Mn, Zn, Br, dietary fibers, and proteinergic/nonproteinergic amino acids.",
#   "Reference": "Nagulapalli Venkata, K. C., Swaroop, A., Bagchi, D., & Bishayee, A. (2017). A small plant with big benefits: Fenugreek (Trigonella foenum-graecum Linn.) for disease prevention and health promotion. Molecular Nutrition & Food Research, 61(6), 1600950. https://doi.org/10.1002/mnfr.201600950"
# }
# ```
# 66
